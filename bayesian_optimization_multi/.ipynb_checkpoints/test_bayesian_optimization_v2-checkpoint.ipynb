# %%
import pandas as pd
import matplotlib.pyplot as plt
import spatial_efd
import math 
import signac
import numpy as np
import os.path
import os
import torch
import gpytorch
from matplotlib import pyplot as plt
from sklearn.preprocessing import StandardScaler
from smt.sampling_methods import LHS
# Importing helper libraries for bayesian optimization
from dependencies.data_preprocessing_class import dataPreprocessing
from dependencies.gaussian_process_regression_class import gaussianProcessRegression
from dependencies.acquisition_functions_class import acqisitionFunctions
from dependencies.geometry_writer import geometryWriter
from dependencies.feature_extractor_4 import FeatureExtractor

# %%
# Checking if data exists
doesDataFileExist = os.path.isfile("master_feature_output.npy")
# Loading datafiles if they exist
# Else fetching and preparing data from signac workspace
if doesDataFileExist == True:
	master_parameter_input_n = np.load('master_parameter_input_n.npy', )
	master_feature_output = np.load('master_feature_output.npy', )

# %%
data_efd_mean = np.mean(master_feature_output,axis = 0)
data_efd_variance = np.std(master_feature_output,axis = 0)
data_efd_variance[0,] = 10**-33
# Loading in the data processing class
dataPreprocess  = dataPreprocessing(master_parameter_input_n, master_feature_output, 133)
# Converting the input parameters to logscale
master_parameter_input_log = dataPreprocess.inputLogTransform()
# Selecting the parameters that were sampled in the latin hypercube sampling
num_parameters_LHS = 7
LHS_parameter_index = [1, 4, 7, 17, 18, 19, 33]
# Calling in the function to separate out the desired parameters
data_x = dataPreprocess.inputParameterSelection(num_parameters_LHS, LHS_parameter_index, master_parameter_input_log)
# PCA to reduce dimensionality of the output data
total_variance_explained, principalComponents, weights = dataPreprocess.pcaEfdFeatures(8)
# Storing mean and standard deviation of input training data for later use
data_x_mean = np.mean(data_x, axis=0)
data_x_variance = np.std(data_x, axis=0)
# Normalizing data
data_x = StandardScaler().fit_transform(data_x)
# Selecting PC1 as our 1st output to the multidimensional input
data_y = principalComponents[:,0]


max_data_x = np.amax(data_x, axis=0) 
min_data_x = np.amin(data_x, axis=0) 
print(max_data_x)
print(min_data_x)
# Out:
# [1.42079434 1.41813797 1.44579386 1.40938397 1.4086535  1.40883561
#  1.3508899 ]
# [-1.81937813 -1.93823379 -1.87646633 -1.78401882 -1.8260345  -1.91939962
#  -1.8461721 ]
# /home/nkumar4/Desktop/bayesian_optimization/dependencies/data_preprocessing_class.py:42: RuntimeWarning: divide by zero encountered in log
#   master_parameter_input = np.log(self.master_parameter_input_n)

# %%
# Reading the vertices output file from a sample SE simulation output with known parameters
fe_exp = FeatureExtractor('input_data/vertices_target_SE.txt', 'log_edges.xlsx')
# Extracting the efd coefficients
coeff_exp = fe_exp.tissue_efd_coeff(20)
# Reverse EFD for plotting the normalized tissue shape
xt_exp, yt_exp = spatial_efd.inverse_transform(coeff_exp, harmonic=20)
efd_coeff_exp_reshaped = np.reshape(coeff_exp, (80,))

efd_coeff_exp_normalized = (np.divide(np.subtract(efd_coeff_exp_reshaped,data_efd_mean), data_efd_variance)) 
efd_coeff_exp_normalized = np.reshape(efd_coeff_exp_normalized, (80,1))
# Multiplying EFD coefficients by already obtained weight of pc
efd_coeff_exp_normalized_pc = np.matmul(weights,efd_coeff_exp_normalized)
# Reshaping array for appending to the original data array
y_exp = np.reshape(efd_coeff_exp_normalized_pc, (1,8))
y_target = efd_coeff_exp_normalized_pc[0]

# %%
print(y_target)
# Out:
# [-2.27741185]

# %%
class ExactGPModel(gpytorch.models.ExactGP):
	def __init__(self, train_x, train_y, likelihood):
		super(ExactGPModel, self).__init__(train_x, train_y, likelihood)
		self.mean_module = gpytorch.means.ConstantMean()
		self.covar_module = gpytorch.kernels.ScaleKernel(gpytorch.kernels.MaternKernel(nu=0.5))
		
	def forward(self, x):
		mean_x = self.mean_module(x)
		covar_x = self.covar_module(x)
		return gpytorch.distributions.MultivariateNormal(mean_x, covar_x)
# Calling in the gpr class
gpr  = gaussianProcessRegression(data_x, data_y)
# Splitting up the training and test data
train_x, train_y, test_x, test_y = gpr.split_data(110, 133)

# %%
model, likelihood = gpr.GP_Regressor(train_x, train_y, test_x, test_y, 1000, 1, ExactGPModel)
# Out:
# Iter 1/1000 - Loss: 6.599   lengthscale: 0.693   noise: 0.693
# Iter 2/1000 - Loss: 6.170   lengthscale: 0.744   noise: 0.744
# Iter 3/1000 - Loss: 5.798   lengthscale: 0.798   noise: 0.798
# Iter 4/1000 - Loss: 5.477   lengthscale: 0.853   noise: 0.853
# Iter 5/1000 - Loss: 5.200   lengthscale: 0.909   noise: 0.911
# Iter 6/1000 - Loss: 4.960   lengthscale: 0.965   noise: 0.969
# Iter 7/1000 - Loss: 4.752   lengthscale: 1.022   noise: 1.029
# Iter 8/1000 - Loss: 4.571   lengthscale: 1.077   noise: 1.090
# Iter 9/1000 - Loss: 4.413   lengthscale: 1.131   noise: 1.151
# Iter 10/1000 - Loss: 4.274   lengthscale: 1.183   noise: 1.213
# Iter 11/1000 - Loss: 4.151   lengthscale: 1.232   noise: 1.275
# Iter 12/1000 - Loss: 4.042   lengthscale: 1.279   noise: 1.337
# Iter 13/1000 - Loss: 3.946   lengthscale: 1.322   noise: 1.399
# Iter 14/1000 - Loss: 3.859   lengthscale: 1.362   noise: 1.460
# Iter 15/1000 - Loss: 3.782   lengthscale: 1.399   noise: 1.521
# Iter 16/1000 - Loss: 3.712   lengthscale: 1.433   noise: 1.581
# Iter 17/1000 - Loss: 3.649   lengthscale: 1.463   noise: 1.641
# Iter 18/1000 - Loss: 3.592   lengthscale: 1.490   noise: 1.699
# Iter 19/1000 - Loss: 3.540   lengthscale: 1.513   noise: 1.757
# Iter 20/1000 - Loss: 3.493   lengthscale: 1.534   noise: 1.813
# Iter 21/1000 - Loss: 3.450   lengthscale: 1.552   noise: 1.868
# Iter 22/1000 - Loss: 3.411   lengthscale: 1.567   noise: 1.922
# Iter 23/1000 - Loss: 3.374   lengthscale: 1.580   noise: 1.975
# Iter 24/1000 - Loss: 3.341   lengthscale: 1.591   noise: 2.027
# Iter 25/1000 - Loss: 3.311   lengthscale: 1.599   noise: 2.077
# Iter 26/1000 - Loss: 3.282   lengthscale: 1.605   noise: 2.126
# Iter 27/1000 - Loss: 3.256   lengthscale: 1.610   noise: 2.174
# Iter 28/1000 - Loss: 3.232   lengthscale: 1.613   noise: 2.220
# Iter 29/1000 - Loss: 3.209   lengthscale: 1.615   noise: 2.265
# Iter 30/1000 - Loss: 3.189   lengthscale: 1.616   noise: 2.309
# Iter 31/1000 - Loss: 3.169   lengthscale: 1.615   noise: 2.352
# Iter 32/1000 - Loss: 3.151   lengthscale: 1.614   noise: 2.393
# Iter 33/1000 - Loss: 3.134   lengthscale: 1.611   noise: 2.433
# Iter 34/1000 - Loss: 3.119   lengthscale: 1.608   noise: 2.472
# Iter 35/1000 - Loss: 3.104   lengthscale: 1.605   noise: 2.510
# Iter 36/1000 - Loss: 3.090   lengthscale: 1.600   noise: 2.547
# Iter 37/1000 - Loss: 3.077   lengthscale: 1.596   noise: 2.583
# Iter 38/1000 - Loss: 3.065   lengthscale: 1.591   noise: 2.618
# Iter 39/1000 - Loss: 3.054   lengthscale: 1.585   noise: 2.652
# Iter 40/1000 - Loss: 3.043   lengthscale: 1.580   noise: 2.684
# Iter 41/1000 - Loss: 3.033   lengthscale: 1.575   noise: 2.716
# Iter 42/1000 - Loss: 3.023   lengthscale: 1.569   noise: 2.747
# Iter 43/1000 - Loss: 3.014   lengthscale: 1.564   noise: 2.778
# Iter 44/1000 - Loss: 3.006   lengthscale: 1.558   noise: 2.807
# Iter 45/1000 - Loss: 2.998   lengthscale: 1.553   noise: 2.836
# Iter 46/1000 - Loss: 2.990   lengthscale: 1.548   noise: 2.863
# Iter 47/1000 - Loss: 2.983   lengthscale: 1.543   noise: 2.890
# Iter 48/1000 - Loss: 2.976   lengthscale: 1.538   noise: 2.917
# Iter 49/1000 - Loss: 2.969   lengthscale: 1.534   noise: 2.943
# Iter 50/1000 - Loss: 2.963   lengthscale: 1.529   noise: 2.968
# Iter 51/1000 - Loss: 2.957   lengthscale: 1.525   noise: 2.992
# Iter 52/1000 - Loss: 2.951   lengthscale: 1.522   noise: 3.016
# Iter 53/1000 - Loss: 2.946   lengthscale: 1.518   noise: 3.039
# Iter 54/1000 - Loss: 2.940   lengthscale: 1.515   noise: 3.062
# Iter 55/1000 - Loss: 2.935   lengthscale: 1.513   noise: 3.085
# Iter 56/1000 - Loss: 2.930   lengthscale: 1.510   noise: 3.106
# Iter 57/1000 - Loss: 2.926   lengthscale: 1.508   noise: 3.128
# Iter 58/1000 - Loss: 2.921   lengthscale: 1.506   noise: 3.149
# Iter 59/1000 - Loss: 2.917   lengthscale: 1.505   noise: 3.169
# Iter 60/1000 - Loss: 2.913   lengthscale: 1.504   noise: 3.189
# Iter 61/1000 - Loss: 2.909   lengthscale: 1.503   noise: 3.209
# Iter 62/1000 - Loss: 2.905   lengthscale: 1.502   noise: 3.228
# Iter 63/1000 - Loss: 2.901   lengthscale: 1.502   noise: 3.247
# Iter 64/1000 - Loss: 2.897   lengthscale: 1.502   noise: 3.266
# Iter 65/1000 - Loss: 2.894   lengthscale: 1.502   noise: 3.284
# Iter 66/1000 - Loss: 2.890   lengthscale: 1.503   noise: 3.302
# Iter 67/1000 - Loss: 2.887   lengthscale: 1.503   noise: 3.320
# Iter 68/1000 - Loss: 2.884   lengthscale: 1.504   noise: 3.337
# Iter 69/1000 - Loss: 2.880   lengthscale: 1.505   noise: 3.355
# Iter 70/1000 - Loss: 2.877   lengthscale: 1.507   noise: 3.371
# Iter 71/1000 - Loss: 2.874   lengthscale: 1.508   noise: 3.388
# Iter 72/1000 - Loss: 2.871   lengthscale: 1.510   noise: 3.404
# Iter 73/1000 - Loss: 2.869   lengthscale: 1.511   noise: 3.421
# Iter 74/1000 - Loss: 2.866   lengthscale: 1.513   noise: 3.436
# Iter 75/1000 - Loss: 2.863   lengthscale: 1.515   noise: 3.452
# Iter 76/1000 - Loss: 2.861   lengthscale: 1.517   noise: 3.468
# Iter 77/1000 - Loss: 2.858   lengthscale: 1.520   noise: 3.483
# Iter 78/1000 - Loss: 2.855   lengthscale: 1.522   noise: 3.498
# Iter 79/1000 - Loss: 2.853   lengthscale: 1.524   noise: 3.513
# Iter 80/1000 - Loss: 2.851   lengthscale: 1.527   noise: 3.528
# Iter 81/1000 - Loss: 2.848   lengthscale: 1.529   noise: 3.542
# Iter 82/1000 - Loss: 2.846   lengthscale: 1.532   noise: 3.557
# Iter 83/1000 - Loss: 2.844   lengthscale: 1.534   noise: 3.571
# Iter 84/1000 - Loss: 2.842   lengthscale: 1.537   noise: 3.585
# Iter 85/1000 - Loss: 2.839   lengthscale: 1.539   noise: 3.599
# Iter 86/1000 - Loss: 2.837   lengthscale: 1.542   noise: 3.612
# Iter 87/1000 - Loss: 2.835   lengthscale: 1.545   noise: 3.626
# Iter 88/1000 - Loss: 2.833   lengthscale: 1.547   noise: 3.639
# Iter 89/1000 - Loss: 2.831   lengthscale: 1.550   noise: 3.653
# Iter 90/1000 - Loss: 2.829   lengthscale: 1.552   noise: 3.666
# Iter 91/1000 - Loss: 2.827   lengthscale: 1.555   noise: 3.679
# Iter 92/1000 - Loss: 2.826   lengthscale: 1.557   noise: 3.692
# Iter 93/1000 - Loss: 2.824   lengthscale: 1.560   noise: 3.705
# Iter 94/1000 - Loss: 2.822   lengthscale: 1.562   noise: 3.717
# Iter 95/1000 - Loss: 2.820   lengthscale: 1.565   noise: 3.730
# Iter 96/1000 - Loss: 2.819   lengthscale: 1.567   noise: 3.742
# Iter 97/1000 - Loss: 2.817   lengthscale: 1.570   noise: 3.754
# Iter 98/1000 - Loss: 2.815   lengthscale: 1.572   noise: 3.767
# Iter 99/1000 - Loss: 2.814   lengthscale: 1.574   noise: 3.779
# Iter 100/1000 - Loss: 2.812   lengthscale: 1.576   noise: 3.791
# Iter 101/1000 - Loss: 2.810   lengthscale: 1.579   noise: 3.803
# Iter 102/1000 - Loss: 2.809   lengthscale: 1.581   noise: 3.814
# Iter 103/1000 - Loss: 2.807   lengthscale: 1.583   noise: 3.826
# Iter 104/1000 - Loss: 2.806   lengthscale: 1.585   noise: 3.838
# Iter 105/1000 - Loss: 2.804   lengthscale: 1.587   noise: 3.849
# Iter 106/1000 - Loss: 2.803   lengthscale: 1.589   noise: 3.860
# Iter 107/1000 - Loss: 2.801   lengthscale: 1.591   noise: 3.872
# Iter 108/1000 - Loss: 2.800   lengthscale: 1.593   noise: 3.883
# Iter 109/1000 - Loss: 2.799   lengthscale: 1.595   noise: 3.894
# Iter 110/1000 - Loss: 2.797   lengthscale: 1.597   noise: 3.905
# Iter 111/1000 - Loss: 2.796   lengthscale: 1.599   noise: 3.916
# Iter 112/1000 - Loss: 2.795   lengthscale: 1.601   noise: 3.926
# Iter 113/1000 - Loss: 2.793   lengthscale: 1.602   noise: 3.937
# Iter 114/1000 - Loss: 2.792   lengthscale: 1.604   noise: 3.948
# Iter 115/1000 - Loss: 2.791   lengthscale: 1.606   noise: 3.958
# Iter 116/1000 - Loss: 2.790   lengthscale: 1.608   noise: 3.969
# Iter 117/1000 - Loss: 2.789   lengthscale: 1.609   noise: 3.979
# Iter 118/1000 - Loss: 2.787   lengthscale: 1.611   noise: 3.989
# Iter 119/1000 - Loss: 2.786   lengthscale: 1.613   noise: 4.000
# Iter 120/1000 - Loss: 2.785   lengthscale: 1.614   noise: 4.010
# Iter 121/1000 - Loss: 2.784   lengthscale: 1.616   noise: 4.020
# Iter 122/1000 - Loss: 2.783   lengthscale: 1.618   noise: 4.030
# Iter 123/1000 - Loss: 2.782   lengthscale: 1.619   noise: 4.040
# Iter 124/1000 - Loss: 2.781   lengthscale: 1.621   noise: 4.049
# Iter 125/1000 - Loss: 2.780   lengthscale: 1.622   noise: 4.059
# Iter 126/1000 - Loss: 2.778   lengthscale: 1.624   noise: 4.069
# Iter 127/1000 - Loss: 2.777   lengthscale: 1.625   noise: 4.078
# Iter 128/1000 - Loss: 2.776   lengthscale: 1.627   noise: 4.088
# Iter 129/1000 - Loss: 2.775   lengthscale: 1.628   noise: 4.097
# Iter 130/1000 - Loss: 2.774   lengthscale: 1.630   noise: 4.107
# Iter 131/1000 - Loss: 2.773   lengthscale: 1.631   noise: 4.116
# Iter 132/1000 - Loss: 2.772   lengthscale: 1.633   noise: 4.125
# Iter 133/1000 - Loss: 2.772   lengthscale: 1.634   noise: 4.134
# Iter 134/1000 - Loss: 2.771   lengthscale: 1.636   noise: 4.143
# Iter 135/1000 - Loss: 2.770   lengthscale: 1.637   noise: 4.152
# Iter 136/1000 - Loss: 2.769   lengthscale: 1.639   noise: 4.161
# Iter 137/1000 - Loss: 2.768   lengthscale: 1.640   noise: 4.170
# Iter 138/1000 - Loss: 2.767   lengthscale: 1.642   noise: 4.179
# Iter 139/1000 - Loss: 2.766   lengthscale: 1.643   noise: 4.187
# Iter 140/1000 - Loss: 2.765   lengthscale: 1.645   noise: 4.196
# Iter 141/1000 - Loss: 2.764   lengthscale: 1.646   noise: 4.205
# Iter 142/1000 - Loss: 2.764   lengthscale: 1.647   noise: 4.213
# Iter 143/1000 - Loss: 2.763   lengthscale: 1.649   noise: 4.222
# Iter 144/1000 - Loss: 2.762   lengthscale: 1.650   noise: 4.230
# Iter 145/1000 - Loss: 2.761   lengthscale: 1.652   noise: 4.238
# Iter 146/1000 - Loss: 2.760   lengthscale: 1.653   noise: 4.247
# Iter 147/1000 - Loss: 2.759   lengthscale: 1.655   noise: 4.255
# Iter 148/1000 - Loss: 2.759   lengthscale: 1.656   noise: 4.263
# Iter 149/1000 - Loss: 2.758   lengthscale: 1.657   noise: 4.271
# Iter 150/1000 - Loss: 2.757   lengthscale: 1.659   noise: 4.279
# Iter 151/1000 - Loss: 2.756   lengthscale: 1.660   noise: 4.287
# Iter 152/1000 - Loss: 2.756   lengthscale: 1.662   noise: 4.295
# Iter 153/1000 - Loss: 2.755   lengthscale: 1.663   noise: 4.303
# Iter 154/1000 - Loss: 2.754   lengthscale: 1.664   noise: 4.310
# Iter 155/1000 - Loss: 2.753   lengthscale: 1.666   noise: 4.318
# Iter 156/1000 - Loss: 2.753   lengthscale: 1.667   noise: 4.326
# Iter 157/1000 - Loss: 2.752   lengthscale: 1.669   noise: 4.333
# Iter 158/1000 - Loss: 2.751   lengthscale: 1.670   noise: 4.341
# Iter 159/1000 - Loss: 2.751   lengthscale: 1.671   noise: 4.348
# Iter 160/1000 - Loss: 2.750   lengthscale: 1.673   noise: 4.356
# Iter 161/1000 - Loss: 2.749   lengthscale: 1.674   noise: 4.363
# Iter 162/1000 - Loss: 2.749   lengthscale: 1.676   noise: 4.371
# Iter 163/1000 - Loss: 2.748   lengthscale: 1.677   noise: 4.378
# Iter 164/1000 - Loss: 2.747   lengthscale: 1.678   noise: 4.385
# Iter 165/1000 - Loss: 2.747   lengthscale: 1.680   noise: 4.392
# Iter 166/1000 - Loss: 2.746   lengthscale: 1.681   noise: 4.399
# Iter 167/1000 - Loss: 2.746   lengthscale: 1.682   noise: 4.406
# Iter 168/1000 - Loss: 2.745   lengthscale: 1.684   noise: 4.413
# Iter 169/1000 - Loss: 2.744   lengthscale: 1.685   noise: 4.420
# Iter 170/1000 - Loss: 2.744   lengthscale: 1.687   noise: 4.427
# Iter 171/1000 - Loss: 2.743   lengthscale: 1.688   noise: 4.434
# Iter 172/1000 - Loss: 2.743   lengthscale: 1.689   noise: 4.441
# Iter 173/1000 - Loss: 2.742   lengthscale: 1.691   noise: 4.448
# Iter 174/1000 - Loss: 2.741   lengthscale: 1.692   noise: 4.454
# Iter 175/1000 - Loss: 2.741   lengthscale: 1.693   noise: 4.461
# Iter 176/1000 - Loss: 2.740   lengthscale: 1.695   noise: 4.468
# Iter 177/1000 - Loss: 2.740   lengthscale: 1.696   noise: 4.474
# Iter 178/1000 - Loss: 2.739   lengthscale: 1.697   noise: 4.481
# Iter 179/1000 - Loss: 2.739   lengthscale: 1.699   noise: 4.487
# Iter 180/1000 - Loss: 2.738   lengthscale: 1.700   noise: 4.493
# Iter 181/1000 - Loss: 2.738   lengthscale: 1.701   noise: 4.500
# Iter 182/1000 - Loss: 2.737   lengthscale: 1.703   noise: 4.506
# Iter 183/1000 - Loss: 2.737   lengthscale: 1.704   noise: 4.512
# Iter 184/1000 - Loss: 2.736   lengthscale: 1.705   noise: 4.519
# Iter 185/1000 - Loss: 2.736   lengthscale: 1.707   noise: 4.525
# Iter 186/1000 - Loss: 2.735   lengthscale: 1.708   noise: 4.531
# Iter 187/1000 - Loss: 2.735   lengthscale: 1.709   noise: 4.537
# Iter 188/1000 - Loss: 2.734   lengthscale: 1.711   noise: 4.543
# Iter 189/1000 - Loss: 2.734   lengthscale: 1.712   noise: 4.549
# Iter 190/1000 - Loss: 2.733   lengthscale: 1.713   noise: 4.555
# Iter 191/1000 - Loss: 2.733   lengthscale: 1.714   noise: 4.561
# Iter 192/1000 - Loss: 2.732   lengthscale: 1.716   noise: 4.567
# Iter 193/1000 - Loss: 2.732   lengthscale: 1.717   noise: 4.573
# Iter 194/1000 - Loss: 2.731   lengthscale: 1.718   noise: 4.578
# Iter 195/1000 - Loss: 2.731   lengthscale: 1.720   noise: 4.584
# Iter 196/1000 - Loss: 2.730   lengthscale: 1.721   noise: 4.590
# Iter 197/1000 - Loss: 2.730   lengthscale: 1.722   noise: 4.595
# Iter 198/1000 - Loss: 2.729   lengthscale: 1.723   noise: 4.601
# Iter 199/1000 - Loss: 2.729   lengthscale: 1.725   noise: 4.606
# Iter 200/1000 - Loss: 2.728   lengthscale: 1.726   noise: 4.612
# Iter 201/1000 - Loss: 2.728   lengthscale: 1.727   noise: 4.617
# Iter 202/1000 - Loss: 2.728   lengthscale: 1.728   noise: 4.623
# Iter 203/1000 - Loss: 2.727   lengthscale: 1.730   noise: 4.628
# Iter 204/1000 - Loss: 2.727   lengthscale: 1.731   noise: 4.634
# Iter 205/1000 - Loss: 2.726   lengthscale: 1.732   noise: 4.639
# Iter 206/1000 - Loss: 2.726   lengthscale: 1.733   noise: 4.644
# Iter 207/1000 - Loss: 2.726   lengthscale: 1.735   noise: 4.649
# Iter 208/1000 - Loss: 2.725   lengthscale: 1.736   noise: 4.655
# Iter 209/1000 - Loss: 2.725   lengthscale: 1.737   noise: 4.660
# Iter 210/1000 - Loss: 2.724   lengthscale: 1.738   noise: 4.665
# Iter 211/1000 - Loss: 2.724   lengthscale: 1.740   noise: 4.670
# Iter 212/1000 - Loss: 2.724   lengthscale: 1.741   noise: 4.675
# Iter 213/1000 - Loss: 2.723   lengthscale: 1.742   noise: 4.680
# Iter 214/1000 - Loss: 2.723   lengthscale: 1.743   noise: 4.685
# Iter 215/1000 - Loss: 2.722   lengthscale: 1.744   noise: 4.690
# Iter 216/1000 - Loss: 2.722   lengthscale: 1.746   noise: 4.695
# Iter 217/1000 - Loss: 2.722   lengthscale: 1.747   noise: 4.700
# Iter 218/1000 - Loss: 2.721   lengthscale: 1.748   noise: 4.704
# Iter 219/1000 - Loss: 2.721   lengthscale: 1.749   noise: 4.709
# Iter 220/1000 - Loss: 2.721   lengthscale: 1.750   noise: 4.714
# Iter 221/1000 - Loss: 2.720   lengthscale: 1.752   noise: 4.719
# Iter 222/1000 - Loss: 2.720   lengthscale: 1.753   noise: 4.723
# Iter 223/1000 - Loss: 2.720   lengthscale: 1.754   noise: 4.728
# Iter 224/1000 - Loss: 2.719   lengthscale: 1.755   noise: 4.733
# Iter 225/1000 - Loss: 2.719   lengthscale: 1.756   noise: 4.737
# Iter 226/1000 - Loss: 2.718   lengthscale: 1.758   noise: 4.742
# Iter 227/1000 - Loss: 2.718   lengthscale: 1.759   noise: 4.746
# Iter 228/1000 - Loss: 2.718   lengthscale: 1.760   noise: 4.751
# Iter 229/1000 - Loss: 2.717   lengthscale: 1.761   noise: 4.755
# Iter 230/1000 - Loss: 2.717   lengthscale: 1.762   noise: 4.759
# Iter 231/1000 - Loss: 2.717   lengthscale: 1.763   noise: 4.764
# Iter 232/1000 - Loss: 2.716   lengthscale: 1.765   noise: 4.768
# Iter 233/1000 - Loss: 2.716   lengthscale: 1.766   noise: 4.772
# Iter 234/1000 - Loss: 2.716   lengthscale: 1.767   noise: 4.776
# Iter 235/1000 - Loss: 2.716   lengthscale: 1.768   noise: 4.781
# Iter 236/1000 - Loss: 2.715   lengthscale: 1.769   noise: 4.785
# Iter 237/1000 - Loss: 2.715   lengthscale: 1.770   noise: 4.789
# Iter 238/1000 - Loss: 2.715   lengthscale: 1.772   noise: 4.793
# Iter 239/1000 - Loss: 2.714   lengthscale: 1.773   noise: 4.797
# Iter 240/1000 - Loss: 2.714   lengthscale: 1.774   noise: 4.801
# Iter 241/1000 - Loss: 2.714   lengthscale: 1.775   noise: 4.805
# Iter 242/1000 - Loss: 2.713   lengthscale: 1.776   noise: 4.809
# Iter 243/1000 - Loss: 2.713   lengthscale: 1.777   noise: 4.813
# Iter 244/1000 - Loss: 2.713   lengthscale: 1.778   noise: 4.817
# Iter 245/1000 - Loss: 2.712   lengthscale: 1.780   noise: 4.821
# Iter 246/1000 - Loss: 2.712   lengthscale: 1.781   noise: 4.825
# Iter 247/1000 - Loss: 2.712   lengthscale: 1.782   noise: 4.829
# Iter 248/1000 - Loss: 2.712   lengthscale: 1.783   noise: 4.832
# Iter 249/1000 - Loss: 2.711   lengthscale: 1.784   noise: 4.836
# Iter 250/1000 - Loss: 2.711   lengthscale: 1.785   noise: 4.840
# Iter 251/1000 - Loss: 2.711   lengthscale: 1.786   noise: 4.844
# Iter 252/1000 - Loss: 2.711   lengthscale: 1.787   noise: 4.847
# Iter 253/1000 - Loss: 2.710   lengthscale: 1.788   noise: 4.851
# Iter 254/1000 - Loss: 2.710   lengthscale: 1.790   noise: 4.854
# Iter 255/1000 - Loss: 2.710   lengthscale: 1.791   noise: 4.858
# Iter 256/1000 - Loss: 2.709   lengthscale: 1.792   noise: 4.861
# Iter 257/1000 - Loss: 2.709   lengthscale: 1.793   noise: 4.865
# Iter 258/1000 - Loss: 2.709   lengthscale: 1.794   noise: 4.868
# Iter 259/1000 - Loss: 2.709   lengthscale: 1.795   noise: 4.872
# Iter 260/1000 - Loss: 2.708   lengthscale: 1.796   noise: 4.875
# Iter 261/1000 - Loss: 2.708   lengthscale: 1.797   noise: 4.879
# Iter 262/1000 - Loss: 2.708   lengthscale: 1.798   noise: 4.882
# Iter 263/1000 - Loss: 2.708   lengthscale: 1.799   noise: 4.885
# Iter 264/1000 - Loss: 2.707   lengthscale: 1.800   noise: 4.889
# Iter 265/1000 - Loss: 2.707   lengthscale: 1.802   noise: 4.892
# Iter 266/1000 - Loss: 2.707   lengthscale: 1.803   noise: 4.895
# Iter 267/1000 - Loss: 2.707   lengthscale: 1.804   noise: 4.898
# Iter 268/1000 - Loss: 2.706   lengthscale: 1.805   noise: 4.902
# Iter 269/1000 - Loss: 2.706   lengthscale: 1.806   noise: 4.905
# Iter 270/1000 - Loss: 2.706   lengthscale: 1.807   noise: 4.908
# Iter 271/1000 - Loss: 2.706   lengthscale: 1.808   noise: 4.911
# Iter 272/1000 - Loss: 2.705   lengthscale: 1.809   noise: 4.914
# Iter 273/1000 - Loss: 2.705   lengthscale: 1.810   noise: 4.917
# Iter 274/1000 - Loss: 2.705   lengthscale: 1.811   noise: 4.920
# Iter 275/1000 - Loss: 2.705   lengthscale: 1.812   noise: 4.923
# Iter 276/1000 - Loss: 2.704   lengthscale: 1.813   noise: 4.926
# Iter 277/1000 - Loss: 2.704   lengthscale: 1.814   noise: 4.929
# Iter 278/1000 - Loss: 2.704   lengthscale: 1.815   noise: 4.932
# Iter 279/1000 - Loss: 2.704   lengthscale: 1.816   noise: 4.935
# Iter 280/1000 - Loss: 2.704   lengthscale: 1.817   noise: 4.938
# Iter 281/1000 - Loss: 2.703   lengthscale: 1.818   noise: 4.940
# Iter 282/1000 - Loss: 2.703   lengthscale: 1.819   noise: 4.943
# Iter 283/1000 - Loss: 2.703   lengthscale: 1.820   noise: 4.946
# Iter 284/1000 - Loss: 2.703   lengthscale: 1.821   noise: 4.949
# Iter 285/1000 - Loss: 2.702   lengthscale: 1.822   noise: 4.951
# Iter 286/1000 - Loss: 2.702   lengthscale: 1.823   noise: 4.954
# Iter 287/1000 - Loss: 2.702   lengthscale: 1.825   noise: 4.957
# Iter 288/1000 - Loss: 2.702   lengthscale: 1.826   noise: 4.959
# Iter 289/1000 - Loss: 2.702   lengthscale: 1.827   noise: 4.962
# Iter 290/1000 - Loss: 2.701   lengthscale: 1.828   noise: 4.965
# Iter 291/1000 - Loss: 2.701   lengthscale: 1.829   noise: 4.967
# Iter 292/1000 - Loss: 2.701   lengthscale: 1.830   noise: 4.970
# Iter 293/1000 - Loss: 2.701   lengthscale: 1.831   noise: 4.972
# Iter 294/1000 - Loss: 2.701   lengthscale: 1.832   noise: 4.975
# Iter 295/1000 - Loss: 2.700   lengthscale: 1.833   noise: 4.977
# Iter 296/1000 - Loss: 2.700   lengthscale: 1.834   noise: 4.980
# Iter 297/1000 - Loss: 2.700   lengthscale: 1.835   noise: 4.982
# Iter 298/1000 - Loss: 2.700   lengthscale: 1.836   noise: 4.984
# Iter 299/1000 - Loss: 2.700   lengthscale: 1.837   noise: 4.987
# Iter 300/1000 - Loss: 2.699   lengthscale: 1.838   noise: 4.989
# Iter 301/1000 - Loss: 2.699   lengthscale: 1.838   noise: 4.991
# Iter 302/1000 - Loss: 2.699   lengthscale: 1.839   noise: 4.994
# Iter 303/1000 - Loss: 2.699   lengthscale: 1.840   noise: 4.996
# Iter 304/1000 - Loss: 2.699   lengthscale: 1.841   noise: 4.998
# Iter 305/1000 - Loss: 2.698   lengthscale: 1.842   noise: 5.000
# Iter 306/1000 - Loss: 2.698   lengthscale: 1.843   noise: 5.002
# Iter 307/1000 - Loss: 2.698   lengthscale: 1.844   noise: 5.005
# Iter 308/1000 - Loss: 2.698   lengthscale: 1.845   noise: 5.007
# Iter 309/1000 - Loss: 2.698   lengthscale: 1.846   noise: 5.009
# Iter 310/1000 - Loss: 2.697   lengthscale: 1.847   noise: 5.011
# Iter 311/1000 - Loss: 2.697   lengthscale: 1.848   noise: 5.013
# Iter 312/1000 - Loss: 2.697   lengthscale: 1.849   noise: 5.015
# Iter 313/1000 - Loss: 2.697   lengthscale: 1.850   noise: 5.017
# Iter 314/1000 - Loss: 2.697   lengthscale: 1.851   noise: 5.019
# Iter 315/1000 - Loss: 2.697   lengthscale: 1.852   noise: 5.021
# Iter 316/1000 - Loss: 2.696   lengthscale: 1.853   noise: 5.023
# Iter 317/1000 - Loss: 2.696   lengthscale: 1.854   noise: 5.025
# Iter 318/1000 - Loss: 2.696   lengthscale: 1.855   noise: 5.027
# Iter 319/1000 - Loss: 2.696   lengthscale: 1.856   noise: 5.029
# Iter 320/1000 - Loss: 2.696   lengthscale: 1.857   noise: 5.030
# Iter 321/1000 - Loss: 2.696   lengthscale: 1.858   noise: 5.032
# Iter 322/1000 - Loss: 2.695   lengthscale: 1.859   noise: 5.034
# Iter 323/1000 - Loss: 2.695   lengthscale: 1.860   noise: 5.036
# Iter 324/1000 - Loss: 2.695   lengthscale: 1.860   noise: 5.038
# Iter 325/1000 - Loss: 2.695   lengthscale: 1.861   noise: 5.039
# Iter 326/1000 - Loss: 2.695   lengthscale: 1.862   noise: 5.041
# Iter 327/1000 - Loss: 2.695   lengthscale: 1.863   noise: 5.043
# Iter 328/1000 - Loss: 2.694   lengthscale: 1.864   noise: 5.044
# Iter 329/1000 - Loss: 2.694   lengthscale: 1.865   noise: 5.046
# Iter 330/1000 - Loss: 2.694   lengthscale: 1.866   noise: 5.048
# Iter 331/1000 - Loss: 2.694   lengthscale: 1.867   noise: 5.049
# Iter 332/1000 - Loss: 2.694   lengthscale: 1.868   noise: 5.051
# Iter 333/1000 - Loss: 2.694   lengthscale: 1.869   noise: 5.052
# Iter 334/1000 - Loss: 2.693   lengthscale: 1.870   noise: 5.054
# Iter 335/1000 - Loss: 2.693   lengthscale: 1.870   noise: 5.055
# Iter 336/1000 - Loss: 2.693   lengthscale: 1.871   noise: 5.057
# Iter 337/1000 - Loss: 2.693   lengthscale: 1.872   noise: 5.058
# Iter 338/1000 - Loss: 2.693   lengthscale: 1.873   noise: 5.060
# Iter 339/1000 - Loss: 2.693   lengthscale: 1.874   noise: 5.061
# Iter 340/1000 - Loss: 2.692   lengthscale: 1.875   noise: 5.063
# Iter 341/1000 - Loss: 2.692   lengthscale: 1.876   noise: 5.064
# Iter 342/1000 - Loss: 2.692   lengthscale: 1.877   noise: 5.065
# Iter 343/1000 - Loss: 2.692   lengthscale: 1.878   noise: 5.067
# Iter 344/1000 - Loss: 2.692   lengthscale: 1.878   noise: 5.068
# Iter 345/1000 - Loss: 2.692   lengthscale: 1.879   noise: 5.069
# Iter 346/1000 - Loss: 2.692   lengthscale: 1.880   noise: 5.071
# Iter 347/1000 - Loss: 2.691   lengthscale: 1.881   noise: 5.072
# Iter 348/1000 - Loss: 2.691   lengthscale: 1.882   noise: 5.073
# Iter 349/1000 - Loss: 2.691   lengthscale: 1.883   noise: 5.074
# Iter 350/1000 - Loss: 2.691   lengthscale: 1.884   noise: 5.076
# Iter 351/1000 - Loss: 2.691   lengthscale: 1.885   noise: 5.077
# Iter 352/1000 - Loss: 2.691   lengthscale: 1.885   noise: 5.078
# Iter 353/1000 - Loss: 2.690   lengthscale: 1.886   noise: 5.079
# Iter 354/1000 - Loss: 2.690   lengthscale: 1.887   noise: 5.080
# Iter 355/1000 - Loss: 2.690   lengthscale: 1.888   noise: 5.081
# Iter 356/1000 - Loss: 2.690   lengthscale: 1.889   noise: 5.082
# Iter 357/1000 - Loss: 2.690   lengthscale: 1.890   noise: 5.083
# Iter 358/1000 - Loss: 2.690   lengthscale: 1.891   noise: 5.084
# Iter 359/1000 - Loss: 2.690   lengthscale: 1.891   noise: 5.085
# Iter 360/1000 - Loss: 2.689   lengthscale: 1.892   noise: 5.086
# Iter 361/1000 - Loss: 2.689   lengthscale: 1.893   noise: 5.087
# Iter 362/1000 - Loss: 2.689   lengthscale: 1.894   noise: 5.088
# Iter 363/1000 - Loss: 2.689   lengthscale: 1.895   noise: 5.089
# Iter 364/1000 - Loss: 2.689   lengthscale: 1.896   noise: 5.090
# Iter 365/1000 - Loss: 2.689   lengthscale: 1.896   noise: 5.091
# Iter 366/1000 - Loss: 2.689   lengthscale: 1.897   noise: 5.092
# Iter 367/1000 - Loss: 2.689   lengthscale: 1.898   noise: 5.093
# Iter 368/1000 - Loss: 2.688   lengthscale: 1.899   noise: 5.094
# Iter 369/1000 - Loss: 2.688   lengthscale: 1.900   noise: 5.094
# Iter 370/1000 - Loss: 2.688   lengthscale: 1.901   noise: 5.095
# Iter 371/1000 - Loss: 2.688   lengthscale: 1.901   noise: 5.096
# Iter 372/1000 - Loss: 2.688   lengthscale: 1.902   noise: 5.097
# Iter 373/1000 - Loss: 2.688   lengthscale: 1.903   noise: 5.098
# Iter 374/1000 - Loss: 2.688   lengthscale: 1.904   noise: 5.098
# Iter 375/1000 - Loss: 2.687   lengthscale: 1.905   noise: 5.099
# Iter 376/1000 - Loss: 2.687   lengthscale: 1.905   noise: 5.100
# Iter 377/1000 - Loss: 2.687   lengthscale: 1.906   noise: 5.100
# Iter 378/1000 - Loss: 2.687   lengthscale: 1.907   noise: 5.101
# Iter 379/1000 - Loss: 2.687   lengthscale: 1.908   noise: 5.102
# Iter 380/1000 - Loss: 2.687   lengthscale: 1.909   noise: 5.102
# Iter 381/1000 - Loss: 2.687   lengthscale: 1.909   noise: 5.103
# Iter 382/1000 - Loss: 2.687   lengthscale: 1.910   noise: 5.103
# Iter 383/1000 - Loss: 2.686   lengthscale: 1.911   noise: 5.104
# Iter 384/1000 - Loss: 2.686   lengthscale: 1.912   noise: 5.104
# Iter 385/1000 - Loss: 2.686   lengthscale: 1.913   noise: 5.105
# Iter 386/1000 - Loss: 2.686   lengthscale: 1.913   noise: 5.105
# Iter 387/1000 - Loss: 2.686   lengthscale: 1.914   noise: 5.106
# Iter 388/1000 - Loss: 2.686   lengthscale: 1.915   noise: 5.106
# Iter 389/1000 - Loss: 2.686   lengthscale: 1.916   noise: 5.107
# Iter 390/1000 - Loss: 2.686   lengthscale: 1.917   noise: 5.107
# Iter 391/1000 - Loss: 2.685   lengthscale: 1.917   noise: 5.108
# Iter 392/1000 - Loss: 2.685   lengthscale: 1.918   noise: 5.108
# Iter 393/1000 - Loss: 2.685   lengthscale: 1.919   noise: 5.108
# Iter 394/1000 - Loss: 2.685   lengthscale: 1.920   noise: 5.109
# Iter 395/1000 - Loss: 2.685   lengthscale: 1.920   noise: 5.109
# Iter 396/1000 - Loss: 2.685   lengthscale: 1.921   noise: 5.109
# Iter 397/1000 - Loss: 2.685   lengthscale: 1.922   noise: 5.110
# Iter 398/1000 - Loss: 2.685   lengthscale: 1.923   noise: 5.110
# Iter 399/1000 - Loss: 2.684   lengthscale: 1.923   noise: 5.110
# Iter 400/1000 - Loss: 2.684   lengthscale: 1.924   noise: 5.110
# Iter 401/1000 - Loss: 2.684   lengthscale: 1.925   noise: 5.111
# Iter 402/1000 - Loss: 2.684   lengthscale: 1.926   noise: 5.111
# Iter 403/1000 - Loss: 2.684   lengthscale: 1.926   noise: 5.111
# Iter 404/1000 - Loss: 2.684   lengthscale: 1.927   noise: 5.111
# Iter 405/1000 - Loss: 2.684   lengthscale: 1.928   noise: 5.111
# Iter 406/1000 - Loss: 2.684   lengthscale: 1.929   noise: 5.111
# Iter 407/1000 - Loss: 2.684   lengthscale: 1.929   noise: 5.112
# Iter 408/1000 - Loss: 2.683   lengthscale: 1.930   noise: 5.112
# Iter 409/1000 - Loss: 2.683   lengthscale: 1.931   noise: 5.112
# Iter 410/1000 - Loss: 2.683   lengthscale: 1.932   noise: 5.112
# Iter 411/1000 - Loss: 2.683   lengthscale: 1.932   noise: 5.112
# Iter 412/1000 - Loss: 2.683   lengthscale: 1.933   noise: 5.112
# Iter 413/1000 - Loss: 2.683   lengthscale: 1.934   noise: 5.112
# Iter 414/1000 - Loss: 2.683   lengthscale: 1.935   noise: 5.112
# Iter 415/1000 - Loss: 2.683   lengthscale: 1.935   noise: 5.112
# Iter 416/1000 - Loss: 2.683   lengthscale: 1.936   noise: 5.112
# Iter 417/1000 - Loss: 2.682   lengthscale: 1.937   noise: 5.112
# Iter 418/1000 - Loss: 2.682   lengthscale: 1.937   noise: 5.112
# Iter 419/1000 - Loss: 2.682   lengthscale: 1.938   noise: 5.112
# Iter 420/1000 - Loss: 2.682   lengthscale: 1.939   noise: 5.112
# Iter 421/1000 - Loss: 2.682   lengthscale: 1.940   noise: 5.111
# Iter 422/1000 - Loss: 2.682   lengthscale: 1.940   noise: 5.111
# Iter 423/1000 - Loss: 2.682   lengthscale: 1.941   noise: 5.111
# Iter 424/1000 - Loss: 2.682   lengthscale: 1.942   noise: 5.111
# Iter 425/1000 - Loss: 2.682   lengthscale: 1.942   noise: 5.111
# Iter 426/1000 - Loss: 2.681   lengthscale: 1.943   noise: 5.111
# Iter 427/1000 - Loss: 2.681   lengthscale: 1.944   noise: 5.110
# Iter 428/1000 - Loss: 2.681   lengthscale: 1.944   noise: 5.110
# Iter 429/1000 - Loss: 2.681   lengthscale: 1.945   noise: 5.110
# Iter 430/1000 - Loss: 2.681   lengthscale: 1.946   noise: 5.110
# Iter 431/1000 - Loss: 2.681   lengthscale: 1.947   noise: 5.109
# Iter 432/1000 - Loss: 2.681   lengthscale: 1.947   noise: 5.109
# Iter 433/1000 - Loss: 2.681   lengthscale: 1.948   noise: 5.109
# Iter 434/1000 - Loss: 2.681   lengthscale: 1.949   noise: 5.108
# Iter 435/1000 - Loss: 2.680   lengthscale: 1.949   noise: 5.108
# Iter 436/1000 - Loss: 2.680   lengthscale: 1.950   noise: 5.108
# Iter 437/1000 - Loss: 2.680   lengthscale: 1.951   noise: 5.107
# Iter 438/1000 - Loss: 2.680   lengthscale: 1.951   noise: 5.107
# Iter 439/1000 - Loss: 2.680   lengthscale: 1.952   noise: 5.107
# Iter 440/1000 - Loss: 2.680   lengthscale: 1.953   noise: 5.106
# Iter 441/1000 - Loss: 2.680   lengthscale: 1.953   noise: 5.106
# Iter 442/1000 - Loss: 2.680   lengthscale: 1.954   noise: 5.105
# Iter 443/1000 - Loss: 2.680   lengthscale: 1.955   noise: 5.105
# Iter 444/1000 - Loss: 2.680   lengthscale: 1.955   noise: 5.104
# Iter 445/1000 - Loss: 2.679   lengthscale: 1.956   noise: 5.104
# Iter 446/1000 - Loss: 2.679   lengthscale: 1.957   noise: 5.103
# Iter 447/1000 - Loss: 2.679   lengthscale: 1.957   noise: 5.103
# Iter 448/1000 - Loss: 2.679   lengthscale: 1.958   noise: 5.102
# Iter 449/1000 - Loss: 2.679   lengthscale: 1.959   noise: 5.102
# Iter 450/1000 - Loss: 2.679   lengthscale: 1.959   noise: 5.101
# Iter 451/1000 - Loss: 2.679   lengthscale: 1.960   noise: 5.100
# Iter 452/1000 - Loss: 2.679   lengthscale: 1.961   noise: 5.100
# Iter 453/1000 - Loss: 2.679   lengthscale: 1.961   noise: 5.099
# Iter 454/1000 - Loss: 2.679   lengthscale: 1.962   noise: 5.098
# Iter 455/1000 - Loss: 2.678   lengthscale: 1.962   noise: 5.098
# Iter 456/1000 - Loss: 2.678   lengthscale: 1.963   noise: 5.097
# Iter 457/1000 - Loss: 2.678   lengthscale: 1.964   noise: 5.096
# Iter 458/1000 - Loss: 2.678   lengthscale: 1.964   noise: 5.096
# Iter 459/1000 - Loss: 2.678   lengthscale: 1.965   noise: 5.095
# Iter 460/1000 - Loss: 2.678   lengthscale: 1.966   noise: 5.094
# Iter 461/1000 - Loss: 2.678   lengthscale: 1.966   noise: 5.094
# Iter 462/1000 - Loss: 2.678   lengthscale: 1.967   noise: 5.093
# Iter 463/1000 - Loss: 2.678   lengthscale: 1.967   noise: 5.092
# Iter 464/1000 - Loss: 2.678   lengthscale: 1.968   noise: 5.091
# Iter 465/1000 - Loss: 2.677   lengthscale: 1.969   noise: 5.090
# Iter 466/1000 - Loss: 2.677   lengthscale: 1.969   noise: 5.090
# Iter 467/1000 - Loss: 2.677   lengthscale: 1.970   noise: 5.089
# Iter 468/1000 - Loss: 2.677   lengthscale: 1.971   noise: 5.088
# Iter 469/1000 - Loss: 2.677   lengthscale: 1.971   noise: 5.087
# Iter 470/1000 - Loss: 2.677   lengthscale: 1.972   noise: 5.086
# Iter 471/1000 - Loss: 2.677   lengthscale: 1.972   noise: 5.085
# Iter 472/1000 - Loss: 2.677   lengthscale: 1.973   noise: 5.084
# Iter 473/1000 - Loss: 2.677   lengthscale: 1.974   noise: 5.083
# Iter 474/1000 - Loss: 2.677   lengthscale: 1.974   noise: 5.082
# Iter 475/1000 - Loss: 2.677   lengthscale: 1.975   noise: 5.081
# Iter 476/1000 - Loss: 2.676   lengthscale: 1.975   noise: 5.080
# Iter 477/1000 - Loss: 2.676   lengthscale: 1.976   noise: 5.079
# Iter 478/1000 - Loss: 2.676   lengthscale: 1.976   noise: 5.078
# Iter 479/1000 - Loss: 2.676   lengthscale: 1.977   noise: 5.077
# Iter 480/1000 - Loss: 2.676   lengthscale: 1.978   noise: 5.076
# Iter 481/1000 - Loss: 2.676   lengthscale: 1.978   noise: 5.075
# Iter 482/1000 - Loss: 2.676   lengthscale: 1.979   noise: 5.074
# Iter 483/1000 - Loss: 2.676   lengthscale: 1.979   noise: 5.073
# Iter 484/1000 - Loss: 2.676   lengthscale: 1.980   noise: 5.072
# Iter 485/1000 - Loss: 2.676   lengthscale: 1.981   noise: 5.071
# Iter 486/1000 - Loss: 2.675   lengthscale: 1.981   noise: 5.070
# Iter 487/1000 - Loss: 2.675   lengthscale: 1.982   noise: 5.069
# Iter 488/1000 - Loss: 2.675   lengthscale: 1.982   noise: 5.068
# Iter 489/1000 - Loss: 2.675   lengthscale: 1.983   noise: 5.066
# Iter 490/1000 - Loss: 2.675   lengthscale: 1.983   noise: 5.065
# Iter 491/1000 - Loss: 2.675   lengthscale: 1.984   noise: 5.064
# Iter 492/1000 - Loss: 2.675   lengthscale: 1.985   noise: 5.063
# Iter 493/1000 - Loss: 2.675   lengthscale: 1.985   noise: 5.062
# Iter 494/1000 - Loss: 2.675   lengthscale: 1.986   noise: 5.060
# Iter 495/1000 - Loss: 2.675   lengthscale: 1.986   noise: 5.059
# Iter 496/1000 - Loss: 2.675   lengthscale: 1.987   noise: 5.058
# Iter 497/1000 - Loss: 2.675   lengthscale: 1.987   noise: 5.057
# Iter 498/1000 - Loss: 2.674   lengthscale: 1.988   noise: 5.055
# Iter 499/1000 - Loss: 2.674   lengthscale: 1.988   noise: 5.054
# Iter 500/1000 - Loss: 2.674   lengthscale: 1.989   noise: 5.053
# Iter 501/1000 - Loss: 2.674   lengthscale: 1.989   noise: 5.051
# Iter 502/1000 - Loss: 2.674   lengthscale: 1.990   noise: 5.050
# Iter 503/1000 - Loss: 2.674   lengthscale: 1.991   noise: 5.049
# Iter 504/1000 - Loss: 2.674   lengthscale: 1.991   noise: 5.047
# Iter 505/1000 - Loss: 2.674   lengthscale: 1.992   noise: 5.046
# Iter 506/1000 - Loss: 2.674   lengthscale: 1.992   noise: 5.045
# Iter 507/1000 - Loss: 2.674   lengthscale: 1.993   noise: 5.043
# Iter 508/1000 - Loss: 2.674   lengthscale: 1.993   noise: 5.042
# Iter 509/1000 - Loss: 2.673   lengthscale: 1.994   noise: 5.040
# Iter 510/1000 - Loss: 2.673   lengthscale: 1.994   noise: 5.039
# Iter 511/1000 - Loss: 2.673   lengthscale: 1.995   noise: 5.037
# Iter 512/1000 - Loss: 2.673   lengthscale: 1.995   noise: 5.036
# Iter 513/1000 - Loss: 2.673   lengthscale: 1.996   noise: 5.034
# Iter 514/1000 - Loss: 2.673   lengthscale: 1.996   noise: 5.033
# Iter 515/1000 - Loss: 2.673   lengthscale: 1.997   noise: 5.031
# Iter 516/1000 - Loss: 2.673   lengthscale: 1.997   noise: 5.030
# Iter 517/1000 - Loss: 2.673   lengthscale: 1.998   noise: 5.028
# Iter 518/1000 - Loss: 2.673   lengthscale: 1.998   noise: 5.027
# Iter 519/1000 - Loss: 2.673   lengthscale: 1.999   noise: 5.025
# Iter 520/1000 - Loss: 2.673   lengthscale: 1.999   noise: 5.024
# Iter 521/1000 - Loss: 2.672   lengthscale: 2.000   noise: 5.022
# Iter 522/1000 - Loss: 2.672   lengthscale: 2.000   noise: 5.020
# Iter 523/1000 - Loss: 2.672   lengthscale: 2.001   noise: 5.019
# Iter 524/1000 - Loss: 2.672   lengthscale: 2.001   noise: 5.017
# Iter 525/1000 - Loss: 2.672   lengthscale: 2.002   noise: 5.016
# Iter 526/1000 - Loss: 2.672   lengthscale: 2.002   noise: 5.014
# Iter 527/1000 - Loss: 2.672   lengthscale: 2.003   noise: 5.012
# Iter 528/1000 - Loss: 2.672   lengthscale: 2.003   noise: 5.011
# Iter 529/1000 - Loss: 2.672   lengthscale: 2.004   noise: 5.009
# Iter 530/1000 - Loss: 2.672   lengthscale: 2.004   noise: 5.007
# Iter 531/1000 - Loss: 2.672   lengthscale: 2.005   noise: 5.005
# Iter 532/1000 - Loss: 2.671   lengthscale: 2.005   noise: 5.004
# Iter 533/1000 - Loss: 2.671   lengthscale: 2.006   noise: 5.002
# Iter 534/1000 - Loss: 2.671   lengthscale: 2.006   noise: 5.000
# Iter 535/1000 - Loss: 2.671   lengthscale: 2.007   noise: 4.998
# Iter 536/1000 - Loss: 2.671   lengthscale: 2.007   noise: 4.997
# Iter 537/1000 - Loss: 2.671   lengthscale: 2.008   noise: 4.995
# Iter 538/1000 - Loss: 2.671   lengthscale: 2.008   noise: 4.993
# Iter 539/1000 - Loss: 2.671   lengthscale: 2.009   noise: 4.991
# Iter 540/1000 - Loss: 2.671   lengthscale: 2.009   noise: 4.989
# Iter 541/1000 - Loss: 2.671   lengthscale: 2.009   noise: 4.987
# Iter 542/1000 - Loss: 2.671   lengthscale: 2.010   noise: 4.985
# Iter 543/1000 - Loss: 2.671   lengthscale: 2.010   noise: 4.984
# Iter 544/1000 - Loss: 2.671   lengthscale: 2.011   noise: 4.982
# Iter 545/1000 - Loss: 2.670   lengthscale: 2.011   noise: 4.980
# Iter 546/1000 - Loss: 2.670   lengthscale: 2.012   noise: 4.978
# Iter 547/1000 - Loss: 2.670   lengthscale: 2.012   noise: 4.976
# Iter 548/1000 - Loss: 2.670   lengthscale: 2.013   noise: 4.974
# Iter 549/1000 - Loss: 2.670   lengthscale: 2.013   noise: 4.972
# Iter 550/1000 - Loss: 2.670   lengthscale: 2.014   noise: 4.970
# Iter 551/1000 - Loss: 2.670   lengthscale: 2.014   noise: 4.968
# Iter 552/1000 - Loss: 2.670   lengthscale: 2.014   noise: 4.966
# Iter 553/1000 - Loss: 2.670   lengthscale: 2.015   noise: 4.964
# Iter 554/1000 - Loss: 2.670   lengthscale: 2.015   noise: 4.962
# Iter 555/1000 - Loss: 2.670   lengthscale: 2.016   noise: 4.960
# Iter 556/1000 - Loss: 2.670   lengthscale: 2.016   noise: 4.958
# Iter 557/1000 - Loss: 2.669   lengthscale: 2.017   noise: 4.956
# Iter 558/1000 - Loss: 2.669   lengthscale: 2.017   noise: 4.954
# Iter 559/1000 - Loss: 2.669   lengthscale: 2.017   noise: 4.952
# Iter 560/1000 - Loss: 2.669   lengthscale: 2.018   noise: 4.950
# Iter 561/1000 - Loss: 2.669   lengthscale: 2.018   noise: 4.948
# Iter 562/1000 - Loss: 2.669   lengthscale: 2.019   noise: 4.945
# Iter 563/1000 - Loss: 2.669   lengthscale: 2.019   noise: 4.943
# Iter 564/1000 - Loss: 2.669   lengthscale: 2.020   noise: 4.941
# Iter 565/1000 - Loss: 2.669   lengthscale: 2.020   noise: 4.939
# Iter 566/1000 - Loss: 2.669   lengthscale: 2.020   noise: 4.937
# Iter 567/1000 - Loss: 2.669   lengthscale: 2.021   noise: 4.935
# Iter 568/1000 - Loss: 2.669   lengthscale: 2.021   noise: 4.932
# Iter 569/1000 - Loss: 2.668   lengthscale: 2.022   noise: 4.930
# Iter 570/1000 - Loss: 2.668   lengthscale: 2.022   noise: 4.928
# Iter 571/1000 - Loss: 2.668   lengthscale: 2.022   noise: 4.926
# Iter 572/1000 - Loss: 2.668   lengthscale: 2.023   noise: 4.924
# Iter 573/1000 - Loss: 2.668   lengthscale: 2.023   noise: 4.921
# Iter 574/1000 - Loss: 2.668   lengthscale: 2.024   noise: 4.919
# Iter 575/1000 - Loss: 2.668   lengthscale: 2.024   noise: 4.917
# Iter 576/1000 - Loss: 2.668   lengthscale: 2.024   noise: 4.915
# Iter 577/1000 - Loss: 2.668   lengthscale: 2.025   noise: 4.912
# Iter 578/1000 - Loss: 2.668   lengthscale: 2.025   noise: 4.910
# Iter 579/1000 - Loss: 2.668   lengthscale: 2.026   noise: 4.908
# Iter 580/1000 - Loss: 2.668   lengthscale: 2.026   noise: 4.905
# Iter 581/1000 - Loss: 2.668   lengthscale: 2.026   noise: 4.903
# Iter 582/1000 - Loss: 2.667   lengthscale: 2.027   noise: 4.901
# Iter 583/1000 - Loss: 2.667   lengthscale: 2.027   noise: 4.898
# Iter 584/1000 - Loss: 2.667   lengthscale: 2.027   noise: 4.896
# Iter 585/1000 - Loss: 2.667   lengthscale: 2.028   noise: 4.893
# Iter 586/1000 - Loss: 2.667   lengthscale: 2.028   noise: 4.891
# Iter 587/1000 - Loss: 2.667   lengthscale: 2.029   noise: 4.889
# Iter 588/1000 - Loss: 2.667   lengthscale: 2.029   noise: 4.886
# Iter 589/1000 - Loss: 2.667   lengthscale: 2.029   noise: 4.884
# Iter 590/1000 - Loss: 2.667   lengthscale: 2.030   noise: 4.881
# Iter 591/1000 - Loss: 2.667   lengthscale: 2.030   noise: 4.879
# Iter 592/1000 - Loss: 2.667   lengthscale: 2.030   noise: 4.876
# Iter 593/1000 - Loss: 2.667   lengthscale: 2.031   noise: 4.874
# Iter 594/1000 - Loss: 2.667   lengthscale: 2.031   noise: 4.871
# Iter 595/1000 - Loss: 2.666   lengthscale: 2.031   noise: 4.869
# Iter 596/1000 - Loss: 2.666   lengthscale: 2.032   noise: 4.866
# Iter 597/1000 - Loss: 2.666   lengthscale: 2.032   noise: 4.864
# Iter 598/1000 - Loss: 2.666   lengthscale: 2.032   noise: 4.861
# Iter 599/1000 - Loss: 2.666   lengthscale: 2.033   noise: 4.859
# Iter 600/1000 - Loss: 2.666   lengthscale: 2.033   noise: 4.856
# Iter 601/1000 - Loss: 2.666   lengthscale: 2.034   noise: 4.853
# Iter 602/1000 - Loss: 2.666   lengthscale: 2.034   noise: 4.851
# Iter 603/1000 - Loss: 2.666   lengthscale: 2.034   noise: 4.848
# Iter 604/1000 - Loss: 2.666   lengthscale: 2.035   noise: 4.846
# Iter 605/1000 - Loss: 2.666   lengthscale: 2.035   noise: 4.843
# Iter 606/1000 - Loss: 2.666   lengthscale: 2.035   noise: 4.840
# Iter 607/1000 - Loss: 2.666   lengthscale: 2.036   noise: 4.838
# Iter 608/1000 - Loss: 2.665   lengthscale: 2.036   noise: 4.835
# Iter 609/1000 - Loss: 2.665   lengthscale: 2.036   noise: 4.832
# Iter 610/1000 - Loss: 2.665   lengthscale: 2.037   noise: 4.830
# Iter 611/1000 - Loss: 2.665   lengthscale: 2.037   noise: 4.827
# Iter 612/1000 - Loss: 2.665   lengthscale: 2.037   noise: 4.824
# Iter 613/1000 - Loss: 2.665   lengthscale: 2.037   noise: 4.822
# Iter 614/1000 - Loss: 2.665   lengthscale: 2.038   noise: 4.819
# Iter 615/1000 - Loss: 2.665   lengthscale: 2.038   noise: 4.816
# Iter 616/1000 - Loss: 2.665   lengthscale: 2.038   noise: 4.813
# Iter 617/1000 - Loss: 2.665   lengthscale: 2.039   noise: 4.811
# Iter 618/1000 - Loss: 2.665   lengthscale: 2.039   noise: 4.808
# Iter 619/1000 - Loss: 2.665   lengthscale: 2.039   noise: 4.805
# Iter 620/1000 - Loss: 2.665   lengthscale: 2.040   noise: 4.802
# Iter 621/1000 - Loss: 2.664   lengthscale: 2.040   noise: 4.800
# Iter 622/1000 - Loss: 2.664   lengthscale: 2.040   noise: 4.797
# Iter 623/1000 - Loss: 2.664   lengthscale: 2.041   noise: 4.794
# Iter 624/1000 - Loss: 2.664   lengthscale: 2.041   noise: 4.791
# Iter 625/1000 - Loss: 2.664   lengthscale: 2.041   noise: 4.788
# Iter 626/1000 - Loss: 2.664   lengthscale: 2.041   noise: 4.785
# Iter 627/1000 - Loss: 2.664   lengthscale: 2.042   noise: 4.782
# Iter 628/1000 - Loss: 2.664   lengthscale: 2.042   noise: 4.780
# Iter 629/1000 - Loss: 2.664   lengthscale: 2.042   noise: 4.777
# Iter 630/1000 - Loss: 2.664   lengthscale: 2.043   noise: 4.774
# Iter 631/1000 - Loss: 2.664   lengthscale: 2.043   noise: 4.771
# Iter 632/1000 - Loss: 2.664   lengthscale: 2.043   noise: 4.768
# Iter 633/1000 - Loss: 2.664   lengthscale: 2.043   noise: 4.765
# Iter 634/1000 - Loss: 2.663   lengthscale: 2.044   noise: 4.762
# Iter 635/1000 - Loss: 2.663   lengthscale: 2.044   noise: 4.759
# Iter 636/1000 - Loss: 2.663   lengthscale: 2.044   noise: 4.756
# Iter 637/1000 - Loss: 2.663   lengthscale: 2.045   noise: 4.753
# Iter 638/1000 - Loss: 2.663   lengthscale: 2.045   noise: 4.750
# Iter 639/1000 - Loss: 2.663   lengthscale: 2.045   noise: 4.747
# Iter 640/1000 - Loss: 2.663   lengthscale: 2.045   noise: 4.744
# Iter 641/1000 - Loss: 2.663   lengthscale: 2.046   noise: 4.741
# Iter 642/1000 - Loss: 2.663   lengthscale: 2.046   noise: 4.738
# Iter 643/1000 - Loss: 2.663   lengthscale: 2.046   noise: 4.735
# Iter 644/1000 - Loss: 2.663   lengthscale: 2.046   noise: 4.732
# Iter 645/1000 - Loss: 2.663   lengthscale: 2.047   noise: 4.729
# Iter 646/1000 - Loss: 2.663   lengthscale: 2.047   noise: 4.726
# Iter 647/1000 - Loss: 2.662   lengthscale: 2.047   noise: 4.723
# Iter 648/1000 - Loss: 2.662   lengthscale: 2.047   noise: 4.720
# Iter 649/1000 - Loss: 2.662   lengthscale: 2.048   noise: 4.716
# Iter 650/1000 - Loss: 2.662   lengthscale: 2.048   noise: 4.713
# Iter 651/1000 - Loss: 2.662   lengthscale: 2.048   noise: 4.710
# Iter 652/1000 - Loss: 2.662   lengthscale: 2.048   noise: 4.707
# Iter 653/1000 - Loss: 2.662   lengthscale: 2.049   noise: 4.704
# Iter 654/1000 - Loss: 2.662   lengthscale: 2.049   noise: 4.701
# Iter 655/1000 - Loss: 2.662   lengthscale: 2.049   noise: 4.698
# Iter 656/1000 - Loss: 2.662   lengthscale: 2.049   noise: 4.694
# Iter 657/1000 - Loss: 2.662   lengthscale: 2.050   noise: 4.691
# Iter 658/1000 - Loss: 2.662   lengthscale: 2.050   noise: 4.688
# Iter 659/1000 - Loss: 2.662   lengthscale: 2.050   noise: 4.685
# Iter 660/1000 - Loss: 2.661   lengthscale: 2.050   noise: 4.682
# Iter 661/1000 - Loss: 2.661   lengthscale: 2.051   noise: 4.678
# Iter 662/1000 - Loss: 2.661   lengthscale: 2.051   noise: 4.675
# Iter 663/1000 - Loss: 2.661   lengthscale: 2.051   noise: 4.672
# Iter 664/1000 - Loss: 2.661   lengthscale: 2.051   noise: 4.669
# Iter 665/1000 - Loss: 2.661   lengthscale: 2.052   noise: 4.665
# Iter 666/1000 - Loss: 2.661   lengthscale: 2.052   noise: 4.662
# Iter 667/1000 - Loss: 2.661   lengthscale: 2.052   noise: 4.659
# Iter 668/1000 - Loss: 2.661   lengthscale: 2.052   noise: 4.655
# Iter 669/1000 - Loss: 2.661   lengthscale: 2.052   noise: 4.652
# Iter 670/1000 - Loss: 2.661   lengthscale: 2.053   noise: 4.649
# Iter 671/1000 - Loss: 2.661   lengthscale: 2.053   noise: 4.645
# Iter 672/1000 - Loss: 2.661   lengthscale: 2.053   noise: 4.642
# Iter 673/1000 - Loss: 2.661   lengthscale: 2.053   noise: 4.639
# Iter 674/1000 - Loss: 2.660   lengthscale: 2.053   noise: 4.635
# Iter 675/1000 - Loss: 2.660   lengthscale: 2.054   noise: 4.632
# Iter 676/1000 - Loss: 2.660   lengthscale: 2.054   noise: 4.628
# Iter 677/1000 - Loss: 2.660   lengthscale: 2.054   noise: 4.625
# Iter 678/1000 - Loss: 2.660   lengthscale: 2.054   noise: 4.622
# Iter 679/1000 - Loss: 2.660   lengthscale: 2.054   noise: 4.618
# Iter 680/1000 - Loss: 2.660   lengthscale: 2.055   noise: 4.615
# Iter 681/1000 - Loss: 2.660   lengthscale: 2.055   noise: 4.611
# Iter 682/1000 - Loss: 2.660   lengthscale: 2.055   noise: 4.608
# Iter 683/1000 - Loss: 2.660   lengthscale: 2.055   noise: 4.604
# Iter 684/1000 - Loss: 2.660   lengthscale: 2.055   noise: 4.601
# Iter 685/1000 - Loss: 2.660   lengthscale: 2.056   noise: 4.597
# Iter 686/1000 - Loss: 2.660   lengthscale: 2.056   noise: 4.594
# Iter 687/1000 - Loss: 2.659   lengthscale: 2.056   noise: 4.590
# Iter 688/1000 - Loss: 2.659   lengthscale: 2.056   noise: 4.587
# Iter 689/1000 - Loss: 2.659   lengthscale: 2.056   noise: 4.583
# Iter 690/1000 - Loss: 2.659   lengthscale: 2.057   noise: 4.580
# Iter 691/1000 - Loss: 2.659   lengthscale: 2.057   noise: 4.576
# Iter 692/1000 - Loss: 2.659   lengthscale: 2.057   noise: 4.573
# Iter 693/1000 - Loss: 2.659   lengthscale: 2.057   noise: 4.569
# Iter 694/1000 - Loss: 2.659   lengthscale: 2.057   noise: 4.566
# Iter 695/1000 - Loss: 2.659   lengthscale: 2.057   noise: 4.562
# Iter 696/1000 - Loss: 2.659   lengthscale: 2.058   noise: 4.558
# Iter 697/1000 - Loss: 2.659   lengthscale: 2.058   noise: 4.555
# Iter 698/1000 - Loss: 2.659   lengthscale: 2.058   noise: 4.551
# Iter 699/1000 - Loss: 2.659   lengthscale: 2.058   noise: 4.548
# Iter 700/1000 - Loss: 2.659   lengthscale: 2.058   noise: 4.544
# Iter 701/1000 - Loss: 2.658   lengthscale: 2.058   noise: 4.540
# Iter 702/1000 - Loss: 2.658   lengthscale: 2.058   noise: 4.537
# Iter 703/1000 - Loss: 2.658   lengthscale: 2.059   noise: 4.533
# Iter 704/1000 - Loss: 2.658   lengthscale: 2.059   noise: 4.529
# Iter 705/1000 - Loss: 2.658   lengthscale: 2.059   noise: 4.526
# Iter 706/1000 - Loss: 2.658   lengthscale: 2.059   noise: 4.522
# Iter 707/1000 - Loss: 2.658   lengthscale: 2.059   noise: 4.518
# Iter 708/1000 - Loss: 2.658   lengthscale: 2.059   noise: 4.515
# Iter 709/1000 - Loss: 2.658   lengthscale: 2.060   noise: 4.511
# Iter 710/1000 - Loss: 2.658   lengthscale: 2.060   noise: 4.507
# Iter 711/1000 - Loss: 2.658   lengthscale: 2.060   noise: 4.503
# Iter 712/1000 - Loss: 2.658   lengthscale: 2.060   noise: 4.500
# Iter 713/1000 - Loss: 2.658   lengthscale: 2.060   noise: 4.496
# Iter 714/1000 - Loss: 2.657   lengthscale: 2.060   noise: 4.492
# Iter 715/1000 - Loss: 2.657   lengthscale: 2.060   noise: 4.488
# Iter 716/1000 - Loss: 2.657   lengthscale: 2.060   noise: 4.484
# Iter 717/1000 - Loss: 2.657   lengthscale: 2.061   noise: 4.481
# Iter 718/1000 - Loss: 2.657   lengthscale: 2.061   noise: 4.477
# Iter 719/1000 - Loss: 2.657   lengthscale: 2.061   noise: 4.473
# Iter 720/1000 - Loss: 2.657   lengthscale: 2.061   noise: 4.469
# Iter 721/1000 - Loss: 2.657   lengthscale: 2.061   noise: 4.465
# Iter 722/1000 - Loss: 2.657   lengthscale: 2.061   noise: 4.461
# Iter 723/1000 - Loss: 2.657   lengthscale: 2.061   noise: 4.458
# Iter 724/1000 - Loss: 2.657   lengthscale: 2.061   noise: 4.454
# Iter 725/1000 - Loss: 2.657   lengthscale: 2.062   noise: 4.450
# Iter 726/1000 - Loss: 2.657   lengthscale: 2.062   noise: 4.446
# Iter 727/1000 - Loss: 2.656   lengthscale: 2.062   noise: 4.442
# Iter 728/1000 - Loss: 2.656   lengthscale: 2.062   noise: 4.438
# Iter 729/1000 - Loss: 2.656   lengthscale: 2.062   noise: 4.434
# Iter 730/1000 - Loss: 2.656   lengthscale: 2.062   noise: 4.430
# Iter 731/1000 - Loss: 2.656   lengthscale: 2.062   noise: 4.426
# Iter 732/1000 - Loss: 2.656   lengthscale: 2.062   noise: 4.422
# Iter 733/1000 - Loss: 2.656   lengthscale: 2.062   noise: 4.418
# Iter 734/1000 - Loss: 2.656   lengthscale: 2.063   noise: 4.414
# Iter 735/1000 - Loss: 2.656   lengthscale: 2.063   noise: 4.410
# Iter 736/1000 - Loss: 2.656   lengthscale: 2.063   noise: 4.406
# Iter 737/1000 - Loss: 2.656   lengthscale: 2.063   noise: 4.402
# Iter 738/1000 - Loss: 2.656   lengthscale: 2.063   noise: 4.398
# Iter 739/1000 - Loss: 2.656   lengthscale: 2.063   noise: 4.394
# Iter 740/1000 - Loss: 2.656   lengthscale: 2.063   noise: 4.390
# Iter 741/1000 - Loss: 2.655   lengthscale: 2.063   noise: 4.386
# Iter 742/1000 - Loss: 2.655   lengthscale: 2.063   noise: 4.382
# Iter 743/1000 - Loss: 2.655   lengthscale: 2.063   noise: 4.378
# Iter 744/1000 - Loss: 2.655   lengthscale: 2.063   noise: 4.374
# Iter 745/1000 - Loss: 2.655   lengthscale: 2.064   noise: 4.370
# Iter 746/1000 - Loss: 2.655   lengthscale: 2.064   noise: 4.366
# Iter 747/1000 - Loss: 2.655   lengthscale: 2.064   noise: 4.362
# Iter 748/1000 - Loss: 2.655   lengthscale: 2.064   noise: 4.358
# Iter 749/1000 - Loss: 2.655   lengthscale: 2.064   noise: 4.354
# Iter 750/1000 - Loss: 2.655   lengthscale: 2.064   noise: 4.350
# Iter 751/1000 - Loss: 2.655   lengthscale: 2.064   noise: 4.345
# Iter 752/1000 - Loss: 2.655   lengthscale: 2.064   noise: 4.341
# Iter 753/1000 - Loss: 2.655   lengthscale: 2.064   noise: 4.337
# Iter 754/1000 - Loss: 2.654   lengthscale: 2.064   noise: 4.333
# Iter 755/1000 - Loss: 2.654   lengthscale: 2.064   noise: 4.329
# Iter 756/1000 - Loss: 2.654   lengthscale: 2.064   noise: 4.325
# Iter 757/1000 - Loss: 2.654   lengthscale: 2.064   noise: 4.321
# Iter 758/1000 - Loss: 2.654   lengthscale: 2.064   noise: 4.316
# Iter 759/1000 - Loss: 2.654   lengthscale: 2.065   noise: 4.312
# Iter 760/1000 - Loss: 2.654   lengthscale: 2.065   noise: 4.308
# Iter 761/1000 - Loss: 2.654   lengthscale: 2.065   noise: 4.304
# Iter 762/1000 - Loss: 2.654   lengthscale: 2.065   noise: 4.299
# Iter 763/1000 - Loss: 2.654   lengthscale: 2.065   noise: 4.295
# Iter 764/1000 - Loss: 2.654   lengthscale: 2.065   noise: 4.291
# Iter 765/1000 - Loss: 2.654   lengthscale: 2.065   noise: 4.287
# Iter 766/1000 - Loss: 2.654   lengthscale: 2.065   noise: 4.282
# Iter 767/1000 - Loss: 2.653   lengthscale: 2.065   noise: 4.278
# Iter 768/1000 - Loss: 2.653   lengthscale: 2.065   noise: 4.274
# Iter 769/1000 - Loss: 2.653   lengthscale: 2.065   noise: 4.270
# Iter 770/1000 - Loss: 2.653   lengthscale: 2.065   noise: 4.265
# Iter 771/1000 - Loss: 2.653   lengthscale: 2.065   noise: 4.261
# Iter 772/1000 - Loss: 2.653   lengthscale: 2.065   noise: 4.257
# Iter 773/1000 - Loss: 2.653   lengthscale: 2.065   noise: 4.252
# Iter 774/1000 - Loss: 2.653   lengthscale: 2.065   noise: 4.248
# Iter 775/1000 - Loss: 2.653   lengthscale: 2.065   noise: 4.244
# Iter 776/1000 - Loss: 2.653   lengthscale: 2.065   noise: 4.239
# Iter 777/1000 - Loss: 2.653   lengthscale: 2.065   noise: 4.235
# Iter 778/1000 - Loss: 2.653   lengthscale: 2.065   noise: 4.230
# Iter 779/1000 - Loss: 2.653   lengthscale: 2.065   noise: 4.226
# Iter 780/1000 - Loss: 2.652   lengthscale: 2.065   noise: 4.222
# Iter 781/1000 - Loss: 2.652   lengthscale: 2.065   noise: 4.217
# Iter 782/1000 - Loss: 2.652   lengthscale: 2.065   noise: 4.213
# Iter 783/1000 - Loss: 2.652   lengthscale: 2.065   noise: 4.208
# Iter 784/1000 - Loss: 2.652   lengthscale: 2.065   noise: 4.204
# Iter 785/1000 - Loss: 2.652   lengthscale: 2.065   noise: 4.199
# Iter 786/1000 - Loss: 2.652   lengthscale: 2.065   noise: 4.195
# Iter 787/1000 - Loss: 2.652   lengthscale: 2.065   noise: 4.191
# Iter 788/1000 - Loss: 2.652   lengthscale: 2.065   noise: 4.186
# Iter 789/1000 - Loss: 2.652   lengthscale: 2.065   noise: 4.182
# Iter 790/1000 - Loss: 2.652   lengthscale: 2.065   noise: 4.177
# Iter 791/1000 - Loss: 2.652   lengthscale: 2.065   noise: 4.173
# Iter 792/1000 - Loss: 2.652   lengthscale: 2.065   noise: 4.168
# Iter 793/1000 - Loss: 2.651   lengthscale: 2.065   noise: 4.164
# Iter 794/1000 - Loss: 2.651   lengthscale: 2.066   noise: 4.159
# Iter 795/1000 - Loss: 2.651   lengthscale: 2.065   noise: 4.155
# Iter 796/1000 - Loss: 2.651   lengthscale: 2.065   noise: 4.150
# Iter 797/1000 - Loss: 2.651   lengthscale: 2.065   noise: 4.145
# Iter 798/1000 - Loss: 2.651   lengthscale: 2.065   noise: 4.141
# Iter 799/1000 - Loss: 2.651   lengthscale: 2.065   noise: 4.136
# Iter 800/1000 - Loss: 2.651   lengthscale: 2.065   noise: 4.132
# Iter 801/1000 - Loss: 2.651   lengthscale: 2.065   noise: 4.127
# Iter 802/1000 - Loss: 2.651   lengthscale: 2.065   noise: 4.123
# Iter 803/1000 - Loss: 2.651   lengthscale: 2.065   noise: 4.118
# Iter 804/1000 - Loss: 2.651   lengthscale: 2.065   noise: 4.113
# Iter 805/1000 - Loss: 2.651   lengthscale: 2.065   noise: 4.109
# Iter 806/1000 - Loss: 2.651   lengthscale: 2.065   noise: 4.104
# Iter 807/1000 - Loss: 2.650   lengthscale: 2.065   noise: 4.099
# Iter 808/1000 - Loss: 2.650   lengthscale: 2.065   noise: 4.095
# Iter 809/1000 - Loss: 2.650   lengthscale: 2.065   noise: 4.090
# Iter 810/1000 - Loss: 2.650   lengthscale: 2.065   noise: 4.085
# Iter 811/1000 - Loss: 2.650   lengthscale: 2.065   noise: 4.081
# Iter 812/1000 - Loss: 2.650   lengthscale: 2.065   noise: 4.076
# Iter 813/1000 - Loss: 2.650   lengthscale: 2.065   noise: 4.071
# Iter 814/1000 - Loss: 2.650   lengthscale: 2.065   noise: 4.067
# Iter 815/1000 - Loss: 2.650   lengthscale: 2.065   noise: 4.062
# Iter 816/1000 - Loss: 2.650   lengthscale: 2.065   noise: 4.057
# Iter 817/1000 - Loss: 2.650   lengthscale: 2.065   noise: 4.052
# Iter 818/1000 - Loss: 2.650   lengthscale: 2.065   noise: 4.048
# Iter 819/1000 - Loss: 2.649   lengthscale: 2.065   noise: 4.043
# Iter 820/1000 - Loss: 2.649   lengthscale: 2.065   noise: 4.038
# Iter 821/1000 - Loss: 2.649   lengthscale: 2.065   noise: 4.033
# Iter 822/1000 - Loss: 2.649   lengthscale: 2.065   noise: 4.029
# Iter 823/1000 - Loss: 2.649   lengthscale: 2.065   noise: 4.024
# Iter 824/1000 - Loss: 2.649   lengthscale: 2.065   noise: 4.019
# Iter 825/1000 - Loss: 2.649   lengthscale: 2.065   noise: 4.014
# Iter 826/1000 - Loss: 2.649   lengthscale: 2.065   noise: 4.009
# Iter 827/1000 - Loss: 2.649   lengthscale: 2.065   noise: 4.005
# Iter 828/1000 - Loss: 2.649   lengthscale: 2.065   noise: 4.000
# Iter 829/1000 - Loss: 2.649   lengthscale: 2.065   noise: 3.995
# Iter 830/1000 - Loss: 2.649   lengthscale: 2.064   noise: 3.990
# Iter 831/1000 - Loss: 2.649   lengthscale: 2.064   noise: 3.985
# Iter 832/1000 - Loss: 2.648   lengthscale: 2.064   noise: 3.980
# Iter 833/1000 - Loss: 2.648   lengthscale: 2.064   noise: 3.976
# Iter 834/1000 - Loss: 2.648   lengthscale: 2.064   noise: 3.971
# Iter 835/1000 - Loss: 2.648   lengthscale: 2.064   noise: 3.966
# Iter 836/1000 - Loss: 2.648   lengthscale: 2.064   noise: 3.961
# Iter 837/1000 - Loss: 2.648   lengthscale: 2.064   noise: 3.956
# Iter 838/1000 - Loss: 2.648   lengthscale: 2.064   noise: 3.951
# Iter 839/1000 - Loss: 2.648   lengthscale: 2.064   noise: 3.946
# Iter 840/1000 - Loss: 2.648   lengthscale: 2.064   noise: 3.941
# Iter 841/1000 - Loss: 2.648   lengthscale: 2.064   noise: 3.936
# Iter 842/1000 - Loss: 2.648   lengthscale: 2.064   noise: 3.931
# Iter 843/1000 - Loss: 2.648   lengthscale: 2.064   noise: 3.926
# Iter 844/1000 - Loss: 2.648   lengthscale: 2.064   noise: 3.921
# Iter 845/1000 - Loss: 2.647   lengthscale: 2.063   noise: 3.916
# Iter 846/1000 - Loss: 2.647   lengthscale: 2.063   noise: 3.911
# Iter 847/1000 - Loss: 2.647   lengthscale: 2.063   noise: 3.906
# Iter 848/1000 - Loss: 2.647   lengthscale: 2.063   noise: 3.901
# Iter 849/1000 - Loss: 2.647   lengthscale: 2.063   noise: 3.896
# Iter 850/1000 - Loss: 2.647   lengthscale: 2.063   noise: 3.891
# Iter 851/1000 - Loss: 2.647   lengthscale: 2.063   noise: 3.886
# Iter 852/1000 - Loss: 2.647   lengthscale: 2.063   noise: 3.881
# Iter 853/1000 - Loss: 2.647   lengthscale: 2.063   noise: 3.876
# Iter 854/1000 - Loss: 2.647   lengthscale: 2.063   noise: 3.871
# Iter 855/1000 - Loss: 2.647   lengthscale: 2.063   noise: 3.866
# Iter 856/1000 - Loss: 2.647   lengthscale: 2.063   noise: 3.861
# Iter 857/1000 - Loss: 2.647   lengthscale: 2.062   noise: 3.856
# Iter 858/1000 - Loss: 2.646   lengthscale: 2.062   noise: 3.851
# Iter 859/1000 - Loss: 2.646   lengthscale: 2.062   noise: 3.846
# Iter 860/1000 - Loss: 2.646   lengthscale: 2.062   noise: 3.841
# Iter 861/1000 - Loss: 2.646   lengthscale: 2.062   noise: 3.836
# Iter 862/1000 - Loss: 2.646   lengthscale: 2.062   noise: 3.830
# Iter 863/1000 - Loss: 2.646   lengthscale: 2.062   noise: 3.825
# Iter 864/1000 - Loss: 2.646   lengthscale: 2.062   noise: 3.820
# Iter 865/1000 - Loss: 2.646   lengthscale: 2.062   noise: 3.815
# Iter 866/1000 - Loss: 2.646   lengthscale: 2.061   noise: 3.810
# Iter 867/1000 - Loss: 2.646   lengthscale: 2.061   noise: 3.805
# Iter 868/1000 - Loss: 2.646   lengthscale: 2.061   noise: 3.800
# Iter 869/1000 - Loss: 2.646   lengthscale: 2.061   noise: 3.794
# Iter 870/1000 - Loss: 2.645   lengthscale: 2.061   noise: 3.789
# Iter 871/1000 - Loss: 2.645   lengthscale: 2.061   noise: 3.784
# Iter 872/1000 - Loss: 2.645   lengthscale: 2.061   noise: 3.779
# Iter 873/1000 - Loss: 2.645   lengthscale: 2.061   noise: 3.774
# Iter 874/1000 - Loss: 2.645   lengthscale: 2.061   noise: 3.768
# Iter 875/1000 - Loss: 2.645   lengthscale: 2.060   noise: 3.763
# Iter 876/1000 - Loss: 2.645   lengthscale: 2.060   noise: 3.758
# Iter 877/1000 - Loss: 2.645   lengthscale: 2.060   noise: 3.753
# Iter 878/1000 - Loss: 2.645   lengthscale: 2.060   noise: 3.747
# Iter 879/1000 - Loss: 2.645   lengthscale: 2.060   noise: 3.742
# Iter 880/1000 - Loss: 2.645   lengthscale: 2.060   noise: 3.737
# Iter 881/1000 - Loss: 2.645   lengthscale: 2.060   noise: 3.732
# Iter 882/1000 - Loss: 2.645   lengthscale: 2.060   noise: 3.726
# Iter 883/1000 - Loss: 2.644   lengthscale: 2.059   noise: 3.721
# Iter 884/1000 - Loss: 2.644   lengthscale: 2.059   noise: 3.716
# Iter 885/1000 - Loss: 2.644   lengthscale: 2.059   noise: 3.710
# Iter 886/1000 - Loss: 2.644   lengthscale: 2.059   noise: 3.705
# Iter 887/1000 - Loss: 2.644   lengthscale: 2.059   noise: 3.700
# Iter 888/1000 - Loss: 2.644   lengthscale: 2.059   noise: 3.694
# Iter 889/1000 - Loss: 2.644   lengthscale: 2.059   noise: 3.689
# Iter 890/1000 - Loss: 2.644   lengthscale: 2.058   noise: 3.684
# Iter 891/1000 - Loss: 2.644   lengthscale: 2.058   noise: 3.678
# Iter 892/1000 - Loss: 2.644   lengthscale: 2.058   noise: 3.673
# Iter 893/1000 - Loss: 2.644   lengthscale: 2.058   noise: 3.668
# Iter 894/1000 - Loss: 2.644   lengthscale: 2.058   noise: 3.662
# Iter 895/1000 - Loss: 2.643   lengthscale: 2.058   noise: 3.657
# Iter 896/1000 - Loss: 2.643   lengthscale: 2.058   noise: 3.651
# Iter 897/1000 - Loss: 2.643   lengthscale: 2.057   noise: 3.646
# Iter 898/1000 - Loss: 2.643   lengthscale: 2.057   noise: 3.640
# Iter 899/1000 - Loss: 2.643   lengthscale: 2.057   noise: 3.635
# Iter 900/1000 - Loss: 2.643   lengthscale: 2.057   noise: 3.630
# Iter 901/1000 - Loss: 2.643   lengthscale: 2.057   noise: 3.624
# Iter 902/1000 - Loss: 2.643   lengthscale: 2.057   noise: 3.619
# Iter 903/1000 - Loss: 2.643   lengthscale: 2.056   noise: 3.613
# Iter 904/1000 - Loss: 2.643   lengthscale: 2.056   noise: 3.608
# Iter 905/1000 - Loss: 2.643   lengthscale: 2.056   noise: 3.602
# Iter 906/1000 - Loss: 2.643   lengthscale: 2.056   noise: 3.597
# Iter 907/1000 - Loss: 2.642   lengthscale: 2.056   noise: 3.591
# Iter 908/1000 - Loss: 2.642   lengthscale: 2.056   noise: 3.586
# Iter 909/1000 - Loss: 2.642   lengthscale: 2.056   noise: 3.580
# Iter 910/1000 - Loss: 2.642   lengthscale: 2.055   noise: 3.575
# Iter 911/1000 - Loss: 2.642   lengthscale: 2.055   noise: 3.569
# Iter 912/1000 - Loss: 2.642   lengthscale: 2.055   noise: 3.564
# Iter 913/1000 - Loss: 2.642   lengthscale: 2.055   noise: 3.558
# Iter 914/1000 - Loss: 2.642   lengthscale: 2.055   noise: 3.553
# Iter 915/1000 - Loss: 2.642   lengthscale: 2.054   noise: 3.547
# Iter 916/1000 - Loss: 2.642   lengthscale: 2.054   noise: 3.542
# Iter 917/1000 - Loss: 2.642   lengthscale: 2.054   noise: 3.536
# Iter 918/1000 - Loss: 2.642   lengthscale: 2.054   noise: 3.530
# Iter 919/1000 - Loss: 2.642   lengthscale: 2.054   noise: 3.525
# Iter 920/1000 - Loss: 2.641   lengthscale: 2.054   noise: 3.519
# Iter 921/1000 - Loss: 2.641   lengthscale: 2.053   noise: 3.514
# Iter 922/1000 - Loss: 2.641   lengthscale: 2.053   noise: 3.508
# Iter 923/1000 - Loss: 2.641   lengthscale: 2.053   noise: 3.502
# Iter 924/1000 - Loss: 2.641   lengthscale: 2.053   noise: 3.497
# Iter 925/1000 - Loss: 2.641   lengthscale: 2.053   noise: 3.491
# Iter 926/1000 - Loss: 2.641   lengthscale: 2.052   noise: 3.485
# Iter 927/1000 - Loss: 2.641   lengthscale: 2.052   noise: 3.480
# Iter 928/1000 - Loss: 2.641   lengthscale: 2.052   noise: 3.474
# Iter 929/1000 - Loss: 2.641   lengthscale: 2.052   noise: 3.468
# Iter 930/1000 - Loss: 2.641   lengthscale: 2.052   noise: 3.463
# Iter 931/1000 - Loss: 2.641   lengthscale: 2.052   noise: 3.457
# Iter 932/1000 - Loss: 2.640   lengthscale: 2.051   noise: 3.451
# Iter 933/1000 - Loss: 2.640   lengthscale: 2.051   noise: 3.446
# Iter 934/1000 - Loss: 2.640   lengthscale: 2.051   noise: 3.440
# Iter 935/1000 - Loss: 2.640   lengthscale: 2.051   noise: 3.434
# Iter 936/1000 - Loss: 2.640   lengthscale: 2.051   noise: 3.429
# Iter 937/1000 - Loss: 2.640   lengthscale: 2.050   noise: 3.423
# Iter 938/1000 - Loss: 2.640   lengthscale: 2.050   noise: 3.417
# Iter 939/1000 - Loss: 2.640   lengthscale: 2.050   noise: 3.411
# Iter 940/1000 - Loss: 2.640   lengthscale: 2.050   noise: 3.406
# Iter 941/1000 - Loss: 2.640   lengthscale: 2.050   noise: 3.400
# Iter 942/1000 - Loss: 2.640   lengthscale: 2.049   noise: 3.394
# Iter 943/1000 - Loss: 2.639   lengthscale: 2.049   noise: 3.388
# Iter 944/1000 - Loss: 2.639   lengthscale: 2.049   noise: 3.382
# Iter 945/1000 - Loss: 2.639   lengthscale: 2.049   noise: 3.377
# Iter 946/1000 - Loss: 2.639   lengthscale: 2.048   noise: 3.371
# Iter 947/1000 - Loss: 2.639   lengthscale: 2.048   noise: 3.365
# Iter 948/1000 - Loss: 2.639   lengthscale: 2.048   noise: 3.359
# Iter 949/1000 - Loss: 2.639   lengthscale: 2.048   noise: 3.353
# Iter 950/1000 - Loss: 2.639   lengthscale: 2.048   noise: 3.348
# Iter 951/1000 - Loss: 2.639   lengthscale: 2.047   noise: 3.342
# Iter 952/1000 - Loss: 2.639   lengthscale: 2.047   noise: 3.336
# Iter 953/1000 - Loss: 2.639   lengthscale: 2.047   noise: 3.330
# Iter 954/1000 - Loss: 2.639   lengthscale: 2.047   noise: 3.324
# Iter 955/1000 - Loss: 2.638   lengthscale: 2.046   noise: 3.318
# Iter 956/1000 - Loss: 2.638   lengthscale: 2.046   noise: 3.312
# Iter 957/1000 - Loss: 2.638   lengthscale: 2.046   noise: 3.307
# Iter 958/1000 - Loss: 2.638   lengthscale: 2.046   noise: 3.301
# Iter 959/1000 - Loss: 2.638   lengthscale: 2.046   noise: 3.295
# Iter 960/1000 - Loss: 2.638   lengthscale: 2.045   noise: 3.289
# Iter 961/1000 - Loss: 2.638   lengthscale: 2.045   noise: 3.283
# Iter 962/1000 - Loss: 2.638   lengthscale: 2.045   noise: 3.277
# Iter 963/1000 - Loss: 2.638   lengthscale: 2.045   noise: 3.271
# Iter 964/1000 - Loss: 2.638   lengthscale: 2.044   noise: 3.265
# Iter 965/1000 - Loss: 2.638   lengthscale: 2.044   noise: 3.259
# Iter 966/1000 - Loss: 2.638   lengthscale: 2.044   noise: 3.253
# Iter 967/1000 - Loss: 2.637   lengthscale: 2.044   noise: 3.247
# Iter 968/1000 - Loss: 2.637   lengthscale: 2.044   noise: 3.241
# Iter 969/1000 - Loss: 2.637   lengthscale: 2.043   noise: 3.235
# Iter 970/1000 - Loss: 2.637   lengthscale: 2.043   noise: 3.229
# Iter 971/1000 - Loss: 2.637   lengthscale: 2.043   noise: 3.223
# Iter 972/1000 - Loss: 2.637   lengthscale: 2.043   noise: 3.217
# Iter 973/1000 - Loss: 2.637   lengthscale: 2.042   noise: 3.211
# Iter 974/1000 - Loss: 2.637   lengthscale: 2.042   noise: 3.205
# Iter 975/1000 - Loss: 2.637   lengthscale: 2.042   noise: 3.199
# Iter 976/1000 - Loss: 2.637   lengthscale: 2.042   noise: 3.193
# Iter 977/1000 - Loss: 2.637   lengthscale: 2.041   noise: 3.187
# Iter 978/1000 - Loss: 2.636   lengthscale: 2.041   noise: 3.181
# Iter 979/1000 - Loss: 2.636   lengthscale: 2.041   noise: 3.175
# Iter 980/1000 - Loss: 2.636   lengthscale: 2.041   noise: 3.169
# Iter 981/1000 - Loss: 2.636   lengthscale: 2.040   noise: 3.163
# Iter 982/1000 - Loss: 2.636   lengthscale: 2.040   noise: 3.157
# Iter 983/1000 - Loss: 2.636   lengthscale: 2.040   noise: 3.151
# Iter 984/1000 - Loss: 2.636   lengthscale: 2.040   noise: 3.145
# Iter 985/1000 - Loss: 2.636   lengthscale: 2.039   noise: 3.139
# Iter 986/1000 - Loss: 2.636   lengthscale: 2.039   noise: 3.133
# Iter 987/1000 - Loss: 2.636   lengthscale: 2.039   noise: 3.127
# Iter 988/1000 - Loss: 2.636   lengthscale: 2.039   noise: 3.120
# Iter 989/1000 - Loss: 2.636   lengthscale: 2.038   noise: 3.114
# Iter 990/1000 - Loss: 2.635   lengthscale: 2.038   noise: 3.108
# Iter 991/1000 - Loss: 2.635   lengthscale: 2.038   noise: 3.102
# Iter 992/1000 - Loss: 2.635   lengthscale: 2.038   noise: 3.096
# Iter 993/1000 - Loss: 2.635   lengthscale: 2.037   noise: 3.090
# Iter 994/1000 - Loss: 2.635   lengthscale: 2.037   noise: 3.084
# Iter 995/1000 - Loss: 2.635   lengthscale: 2.037   noise: 3.077
# Iter 996/1000 - Loss: 2.635   lengthscale: 2.036   noise: 3.071
# Iter 997/1000 - Loss: 2.635   lengthscale: 2.036   noise: 3.065
# Iter 998/1000 - Loss: 2.635   lengthscale: 2.036   noise: 3.059
# Iter 999/1000 - Loss: 2.635   lengthscale: 2.036   noise: 3.053
# Iter 1000/1000 - Loss: 2.635   lengthscale: 2.035   noise: 3.047

# %%
xlimits = np.array([[min_data_x[0], max_data_x[0]],[min_data_x[1], max_data_x[1]],[min_data_x[2], max_data_x[2]],[min_data_x[3], max_data_x[3]],[min_data_x[4], max_data_x[4]],[min_data_x[5], max_data_x[5]],[min_data_x[6], max_data_x[6]]])
sampling = LHS(xlimits = xlimits)
# Defining numvber of samples
num_samples = 1000000
# Implementing latin hypercube sampling
x = sampling(num_samples)
af = acqisitionFunctions(x, test_x, test_y)
# Calculating the xpected improvement
ei = af.expected_improvement_modified(model, likelihood, y_target)
# Finding the indez that leads to maximum acquisition function
x_sampled_index = np.argmax(ei)
# Assessing the new sampled value
x_sampled_logscale_standardized = x[x_sampled_index,:]
# Converting x sampled into parameter space
# Multiplying by standard deviation and adding the mean pf data
x_sampled = np.exp(np.add(np.multiply(x_sampled_logscale_standardized,data_x_variance), data_x_mean))
print(x_sampled)
# Out:
# [1.30449279e-08 1.86722243e-07 6.55471784e-03 1.37340124e-05
#  1.74317734e-05 4.19454932e-01 1.85126808e-08]

# %%
paraminputs = [0,0.0001,0,0,0,0,0,0.001,0,0,0, 0.1,0.1,10,0.1,0.1,0.1,0.1,10,0.0001,0.001,0.001, 1,1,0.6,0.6,0.6,0.6,0.2,0.1,3,0.6,1.8, 0.001,0.001]
# Repalcaing the parameters with newly sampled values
paraminputs[1] = x_sampled[0,]
# tension cuboidal basal
paraminputs[4] = x_sampled[1,]
# tension columnar basal
paraminputs[7] = x_sampled[2,]
# k columnar apical
paraminputs[17] = x_sampled[3,]
# k columnar basal
paraminputs[18] = x_sampled[4,]
# k columnar lateral
paraminputs[19] = x_sampled[5,]
# K_ECM
paraminputs[33] = x_sampled[6,]
# Defining the set system pressure
param_pressure = 0.001
# Writing geometry file
geometryWriter(paraminputs, param_pressure, 'wingDisc')
# Running surface evolver simulations
# Can be replaced using python subprocess using 
os.system("/home/nkumar4/Desktop/evolver_installation/src/evolver wingDisc.fe")

# %%
fe = FeatureExtractor('vertices.txt', 'log_edges.xlsx')
efd_coeff_sampled = fe.tissue_efd_coeff(20)
efd_coeff_sampled_reshaped = np.reshape(efd_coeff_sampled, (80,))
xt_sampled, yt_sampled = spatial_efd.inverse_transform(efd_coeff_sampled, harmonic=20)

"""Step 5e: Converting EFD to PC space
"""
# normalizing efd coefficients with existing data mean and variance
efd_coeff_sampled_normalized = (np.divide(np.subtract(efd_coeff_sampled_reshaped,data_efd_mean), data_efd_variance))
efd_coeff_sampled_normalized = np.reshape(efd_coeff_sampled_normalized, (80,1))
# Multiplying EFD coefficients by already obtained weight of pc
efd_coeff_sampled_normalized_pc = np.matmul(weights,efd_coeff_sampled_normalized)
# Reshaping array for appending to the original data array
y_sampled = np.reshape(efd_coeff_sampled_normalized_pc, (1,8))
print(y_sampled)

# %%
data_x = np.vstack((data_x, np.reshape(x_sampled,(1,7))))

# %%
train_x = np.vstack((train_x, np.reshape(x_sampled,(1,7))))
train_y = np.append(train_y,y_sampled[:,0],axis=0)
print(np.shape(train_x))
print(np.shape(train_y))

# %%
os.system("rm vertices.txt")

# %%
filename_shape_plot = str(1) + "_sapled_target_xy_plot.svg"
# Plotting target data
plt.plot(xt_exp,yt_exp,'black', label='Target')
# Plotting sampled data
plt.plot(xt_sampled, yt_sampled,'blue', label='Experimental')
plt.axes().set_aspect('equal', 'datalim')
# Labeling axes
plt.xlabel("x [nondimensional]")
plt.ylabel("y [nondimensional]")
# Plotting legends
plt.legend()
plt.savefig("contour_evolution_plots/" + filename_shape_plot)
plt.close()

# Calculating error: Error is calculated as a norm of difference between target and sampled EFD coefficients
error_target_sampled_step =  np.linalg.norm(efd_coeff_exp_reshaped-efd_coeff_sampled_reshaped)
