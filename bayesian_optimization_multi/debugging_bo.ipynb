# %%
# Importing libraries
import pandas as pd
import matplotlib.pyplot as plt
import spatial_efd
import math 
import signac
import numpy as np
import os.path
import os
import torch
import gpytorch
import subprocess
import gc
from matplotlib import pyplot as plt
from sklearn.preprocessing import StandardScaler
from smt.sampling_methods import LHS
# Importing helper libraries for bayesian optimization
from dependencies.data_preprocessing_class import dataPreprocessing
from dependencies.gaussian_process_regression_class import gaussianProcessRegression
from dependencies.acquisition_functions_class import acqisitionFunctions
from dependencies.geometry_writer import geometryWriter
from dependencies.feature_extractor_4 import FeatureExtractor

# %%
"""
STEP 0:
Load the input and output data gennerated by SE model for building a GPR model
"""
# Checking if data exists
doesDataFileExist = os.path.isfile("master_feature_output.npy")
# Loading datafiles if they exist
# Else fetching and preparing data from signac workspace
if doesDataFileExist == True:
	master_parameter_input_n = np.load('master_parameter_input_n.npy', )
	master_feature_output = np.load('master_feature_output.npy', )

# %%
"""
STEP 2a: Data preprocessing
1. Selects the parameters sampled in LHS from total 35 parameters of the SE model
2. PCA on the out shape features.
"""
data_efd_mean = np.mean(master_feature_output,axis = 0)
data_efd_variance = np.std(master_feature_output,axis = 0)
data_efd_variance[0,] = 10**-33
# Loading in the data processing class
dataPreprocess  = dataPreprocessing(master_parameter_input_n, master_feature_output, 133)
# Converting the input parameters to logscale
master_parameter_input_log = dataPreprocess.inputLogTransform()
# Selecting the parameters that were sampled in the latin hypercube sampling
num_parameters_LHS = 7
LHS_parameter_index = [1, 4, 7, 17, 18, 19, 33]
# Calling in the function to separate out the desired parameters
data_x = dataPreprocess.inputParameterSelection(num_parameters_LHS, LHS_parameter_index, master_parameter_input_log)
# PCA to reduce dimensionality of the output data
total_variance_explained, principalComponents, weights, weights_af = dataPreprocess.pcaEfdFeatures(8)
# Storing mean and standard deviation of input training data for later use
data_x_mean = np.mean(data_x, axis=0)
data_x_variance = np.std(data_x, axis=0)
# Normalizing data
data_x = StandardScaler().fit_transform(data_x)
max_data_x = np.amax(data_x, axis=0) 
min_data_x = np.amin(data_x, axis=0) 
# Selecting PC1 as our 1st output to the multidimensional input
data_y = principalComponents
# Out:
# /home/nkumar4/Desktop/bayesian_optimization_multi/dependencies/data_preprocessing_class.py:42: RuntimeWarning: divide by zero encountered in log
#   master_parameter_input = np.log(self.master_parameter_input_n)

# %%
# Reading the vertices output file from a sample SE simulation output with known parameters
fe_exp = FeatureExtractor('input_data/vertices_target_SE.txt', 'log_edges.xlsx')
# Extracting the efd coefficients
coeff_exp = fe_exp.tissue_efd_coeff(20)
# Reverse EFD for plotting the normalized tissue shape
xt_exp, yt_exp = spatial_efd.inverse_transform(coeff_exp, harmonic=20)
efd_coeff_exp_reshaped = np.reshape(coeff_exp, (80,))

efd_coeff_exp_normalized = (np.divide(np.subtract(efd_coeff_exp_reshaped,data_efd_mean), data_efd_variance)) 
efd_coeff_exp_normalized = np.reshape(efd_coeff_exp_normalized, (80,1))
# Multiplying EFD coefficients by already obtained weight of pc
efd_coeff_exp_normalized_pc = np.matmul(weights,efd_coeff_exp_normalized)
# Reshaping array for appending to the original data array
y_exp = np.reshape(efd_coeff_exp_normalized_pc, (1,8))

# %%
"""
Step 3: class ExactGP Model 
        Needs to be executed to execute the 
		  gaussianProcessRegression class 
"""
class ExactGPModel(gpytorch.models.ExactGP):
	def __init__(self, train_x, train_y, likelihood):
		super(ExactGPModel, self).__init__(train_x, train_y, likelihood)
		self.mean_module = gpytorch.means.ConstantMean()
		self.covar_module = gpytorch.kernels.ScaleKernel(gpytorch.kernels.MaternKernel(nu=0.5))
		
	def forward(self, x):
		mean_x = self.mean_module(x)
		covar_x = self.covar_module(x)
		return gpytorch.distributions.MultivariateNormal(mean_x, covar_x)
# Calling in the gpr class
gpr  = gaussianProcessRegression(data_x, data_y)
# Splitting up the training and test data
train_x, train_y, test_x, test_y = gpr.split_data(110, 133)

# %%
"""
Step 5: Executing the loop for bayesian optimization

"""
maxIter = 1
num_pc_components = 8
error_target_sampled = []
iter_counter = []
param_sampled = np.zeros((maxIter,7))

for i in range(maxIter):
    """ Step 5a: Training the GP model 
    """	
    """ Step 5b: Estimating acquisition function
    Sample random points in space
    Use the gpr model to estimate expected improvement
    find optimum x
    Transform to parameter space
    """
    # Method I: latine hypercube sampling
    xlimits = np.array([[min_data_x[0], max_data_x[0]],[min_data_x[1], max_data_x[1]],[min_data_x[2], max_data_x[2]],[min_data_x[3], max_data_x[3]],[min_data_x[4], max_data_x[4]],[min_data_x[5], max_data_x[5]],[min_data_x[6], max_data_x[6]]])
    sampling = LHS(xlimits = xlimits)
    # Defining numvber of samples
    num_samples = 100000
    # Implementing latin hypercube sampling
    x = sampling(num_samples)
    master_acquisition = x


    # Method II: Random sampling
    #num_samples = 1000000
    #x = np.random.rand(num_samples, 7)
    
    ei = np.zeros((num_samples,))
    
    for j in range(num_pc_components):
        # Getting the trained model and likelihood using the training data
        model, likelihood = gpr.GP_Regressor(train_x, train_y, test_x, test_y, 100, i, ExactGPModel,j)
        y_target = efd_coeff_exp_normalized_pc[j]
        # Calling in the acquisition function class
        af = acqisitionFunctions(x, test_x, test_y[:,j])
        ei_comp, model_mean, model_var = af.expected_improvement_modified(model, likelihood, y_target)
        
        
        # Calculating the xpected improvement
        ei = ei + weights_af[j]*ei_comp
        
        master_acquisition = np.hstack((master_acquisition,np.reshape(model_mean,(100000,1))))
        master_acquisition = np.hstack((master_acquisition,np.reshape(model_var,(100000,1))))
        master_acquisition = np.hstack((master_acquisition,np.reshape(ei_comp,(100000,1))))
        
        print(np.shape(master_acquisition))
        
        del model
        del likelihood
        del af
        gc.collect()
# Out:
# Iter 1/100 - Loss: 6.599   lengthscale: 0.693   noise: 0.693
# Iter 2/100 - Loss: 6.170   lengthscale: 0.744   noise: 0.744
# Iter 3/100 - Loss: 5.798   lengthscale: 0.798   noise: 0.798
# Iter 4/100 - Loss: 5.477   lengthscale: 0.853   noise: 0.853
# Iter 5/100 - Loss: 5.200   lengthscale: 0.909   noise: 0.911
# Iter 6/100 - Loss: 4.960   lengthscale: 0.965   noise: 0.969
# Iter 7/100 - Loss: 4.752   lengthscale: 1.022   noise: 1.029
# Iter 8/100 - Loss: 4.571   lengthscale: 1.077   noise: 1.090
# Iter 9/100 - Loss: 4.413   lengthscale: 1.131   noise: 1.151
# Iter 10/100 - Loss: 4.274   lengthscale: 1.183   noise: 1.213
# Iter 11/100 - Loss: 4.151   lengthscale: 1.232   noise: 1.275
# Iter 12/100 - Loss: 4.042   lengthscale: 1.279   noise: 1.337
# Iter 13/100 - Loss: 3.946   lengthscale: 1.322   noise: 1.399
# Iter 14/100 - Loss: 3.859   lengthscale: 1.362   noise: 1.460
# Iter 15/100 - Loss: 3.782   lengthscale: 1.399   noise: 1.521
# Iter 16/100 - Loss: 3.712   lengthscale: 1.433   noise: 1.581
# Iter 17/100 - Loss: 3.649   lengthscale: 1.463   noise: 1.641
# Iter 18/100 - Loss: 3.592   lengthscale: 1.490   noise: 1.699
# Iter 19/100 - Loss: 3.540   lengthscale: 1.513   noise: 1.757
# Iter 20/100 - Loss: 3.493   lengthscale: 1.534   noise: 1.813
# Iter 21/100 - Loss: 3.450   lengthscale: 1.552   noise: 1.868
# Iter 22/100 - Loss: 3.411   lengthscale: 1.567   noise: 1.922
# Iter 23/100 - Loss: 3.374   lengthscale: 1.580   noise: 1.975
# Iter 24/100 - Loss: 3.341   lengthscale: 1.591   noise: 2.027
# Iter 25/100 - Loss: 3.311   lengthscale: 1.599   noise: 2.077
# Iter 26/100 - Loss: 3.282   lengthscale: 1.605   noise: 2.126
# Iter 27/100 - Loss: 3.256   lengthscale: 1.610   noise: 2.174
# Iter 28/100 - Loss: 3.232   lengthscale: 1.613   noise: 2.220
# Iter 29/100 - Loss: 3.209   lengthscale: 1.615   noise: 2.265
# Iter 30/100 - Loss: 3.189   lengthscale: 1.616   noise: 2.309
# Iter 31/100 - Loss: 3.169   lengthscale: 1.615   noise: 2.352
# Iter 32/100 - Loss: 3.151   lengthscale: 1.614   noise: 2.393
# Iter 33/100 - Loss: 3.134   lengthscale: 1.611   noise: 2.433
# Iter 34/100 - Loss: 3.119   lengthscale: 1.608   noise: 2.472
# Iter 35/100 - Loss: 3.104   lengthscale: 1.605   noise: 2.510
# Iter 36/100 - Loss: 3.090   lengthscale: 1.600   noise: 2.547
# Iter 37/100 - Loss: 3.077   lengthscale: 1.596   noise: 2.583
# Iter 38/100 - Loss: 3.065   lengthscale: 1.591   noise: 2.618
# Iter 39/100 - Loss: 3.054   lengthscale: 1.585   noise: 2.652
# Iter 40/100 - Loss: 3.043   lengthscale: 1.580   noise: 2.684
# Iter 41/100 - Loss: 3.033   lengthscale: 1.575   noise: 2.716
# Iter 42/100 - Loss: 3.023   lengthscale: 1.569   noise: 2.747
# Iter 43/100 - Loss: 3.014   lengthscale: 1.564   noise: 2.778
# Iter 44/100 - Loss: 3.006   lengthscale: 1.558   noise: 2.807
# Iter 45/100 - Loss: 2.998   lengthscale: 1.553   noise: 2.836
# Iter 46/100 - Loss: 2.990   lengthscale: 1.548   noise: 2.863
# Iter 47/100 - Loss: 2.983   lengthscale: 1.543   noise: 2.890
# Iter 48/100 - Loss: 2.976   lengthscale: 1.538   noise: 2.917
# Iter 49/100 - Loss: 2.969   lengthscale: 1.534   noise: 2.943
# Iter 50/100 - Loss: 2.963   lengthscale: 1.529   noise: 2.968
# Iter 51/100 - Loss: 2.957   lengthscale: 1.525   noise: 2.992
# Iter 52/100 - Loss: 2.951   lengthscale: 1.522   noise: 3.016
# Iter 53/100 - Loss: 2.946   lengthscale: 1.518   noise: 3.039
# Iter 54/100 - Loss: 2.940   lengthscale: 1.515   noise: 3.062
# Iter 55/100 - Loss: 2.935   lengthscale: 1.513   noise: 3.085
# Iter 56/100 - Loss: 2.930   lengthscale: 1.510   noise: 3.106
# Iter 57/100 - Loss: 2.926   lengthscale: 1.508   noise: 3.128
# Iter 58/100 - Loss: 2.921   lengthscale: 1.506   noise: 3.149
# Iter 59/100 - Loss: 2.917   lengthscale: 1.505   noise: 3.169
# Iter 60/100 - Loss: 2.913   lengthscale: 1.504   noise: 3.189
# Iter 61/100 - Loss: 2.909   lengthscale: 1.503   noise: 3.209
# Iter 62/100 - Loss: 2.905   lengthscale: 1.502   noise: 3.228
# Iter 63/100 - Loss: 2.901   lengthscale: 1.502   noise: 3.247
# Iter 64/100 - Loss: 2.897   lengthscale: 1.502   noise: 3.266
# Iter 65/100 - Loss: 2.894   lengthscale: 1.502   noise: 3.284
# Iter 66/100 - Loss: 2.890   lengthscale: 1.503   noise: 3.302
# Iter 67/100 - Loss: 2.887   lengthscale: 1.503   noise: 3.320
# Iter 68/100 - Loss: 2.884   lengthscale: 1.504   noise: 3.337
# Iter 69/100 - Loss: 2.880   lengthscale: 1.505   noise: 3.355
# Iter 70/100 - Loss: 2.877   lengthscale: 1.507   noise: 3.371
# Iter 71/100 - Loss: 2.874   lengthscale: 1.508   noise: 3.388
# Iter 72/100 - Loss: 2.871   lengthscale: 1.510   noise: 3.404
# Iter 73/100 - Loss: 2.869   lengthscale: 1.511   noise: 3.421
# Iter 74/100 - Loss: 2.866   lengthscale: 1.513   noise: 3.436
# Iter 75/100 - Loss: 2.863   lengthscale: 1.515   noise: 3.452
# Iter 76/100 - Loss: 2.861   lengthscale: 1.517   noise: 3.468
# Iter 77/100 - Loss: 2.858   lengthscale: 1.520   noise: 3.483
# Iter 78/100 - Loss: 2.855   lengthscale: 1.522   noise: 3.498
# Iter 79/100 - Loss: 2.853   lengthscale: 1.524   noise: 3.513
# Iter 80/100 - Loss: 2.851   lengthscale: 1.527   noise: 3.528
# Iter 81/100 - Loss: 2.848   lengthscale: 1.529   noise: 3.542
# Iter 82/100 - Loss: 2.846   lengthscale: 1.532   noise: 3.557
# Iter 83/100 - Loss: 2.844   lengthscale: 1.534   noise: 3.571
# Iter 84/100 - Loss: 2.842   lengthscale: 1.537   noise: 3.585
# Iter 85/100 - Loss: 2.839   lengthscale: 1.539   noise: 3.599
# Iter 86/100 - Loss: 2.837   lengthscale: 1.542   noise: 3.612
# Iter 87/100 - Loss: 2.835   lengthscale: 1.545   noise: 3.626
# Iter 88/100 - Loss: 2.833   lengthscale: 1.547   noise: 3.639
# Iter 89/100 - Loss: 2.831   lengthscale: 1.550   noise: 3.653
# Iter 90/100 - Loss: 2.829   lengthscale: 1.552   noise: 3.666
# Iter 91/100 - Loss: 2.827   lengthscale: 1.555   noise: 3.679
# Iter 92/100 - Loss: 2.826   lengthscale: 1.557   noise: 3.692
# Iter 93/100 - Loss: 2.824   lengthscale: 1.560   noise: 3.705
# Iter 94/100 - Loss: 2.822   lengthscale: 1.562   noise: 3.717
# Iter 95/100 - Loss: 2.820   lengthscale: 1.565   noise: 3.730
# Iter 96/100 - Loss: 2.819   lengthscale: 1.567   noise: 3.742
# Iter 97/100 - Loss: 2.817   lengthscale: 1.570   noise: 3.754
# Iter 98/100 - Loss: 2.815   lengthscale: 1.572   noise: 3.767
# Iter 99/100 - Loss: 2.814   lengthscale: 1.574   noise: 3.779
# Iter 100/100 - Loss: 2.812   lengthscale: 1.576   noise: 3.791
# (100000, 10)
# Iter 1/100 - Loss: 5.526   lengthscale: 0.693   noise: 0.693
# Iter 2/100 - Loss: 5.250   lengthscale: 0.644   noise: 0.744
# Iter 3/100 - Loss: 5.008   lengthscale: 0.604   noise: 0.798
# Iter 4/100 - Loss: 4.790   lengthscale: 0.578   noise: 0.854
# Iter 5/100 - Loss: 4.595   lengthscale: 0.565   noise: 0.911
# Iter 6/100 - Loss: 4.420   lengthscale: 0.561   noise: 0.970
# Iter 7/100 - Loss: 4.264   lengthscale: 0.564   noise: 1.030
# Iter 8/100 - Loss: 4.125   lengthscale: 0.572   noise: 1.092
# Iter 9/100 - Loss: 4.000   lengthscale: 0.582   noise: 1.154
# Iter 10/100 - Loss: 3.888   lengthscale: 0.595   noise: 1.216
# Iter 11/100 - Loss: 3.788   lengthscale: 0.608   noise: 1.279
# Iter 12/100 - Loss: 3.699   lengthscale: 0.622   noise: 1.342
# Iter 13/100 - Loss: 3.619   lengthscale: 0.635   noise: 1.405
# Iter 14/100 - Loss: 3.547   lengthscale: 0.647   noise: 1.467
# Iter 15/100 - Loss: 3.483   lengthscale: 0.658   noise: 1.529
# Iter 16/100 - Loss: 3.425   lengthscale: 0.667   noise: 1.590
# Iter 17/100 - Loss: 3.373   lengthscale: 0.674   noise: 1.650
# Iter 18/100 - Loss: 3.326   lengthscale: 0.679   noise: 1.709
# Iter 19/100 - Loss: 3.283   lengthscale: 0.682   noise: 1.767
# Iter 20/100 - Loss: 3.245   lengthscale: 0.683   noise: 1.824
# Iter 21/100 - Loss: 3.210   lengthscale: 0.682   noise: 1.879
# Iter 22/100 - Loss: 3.178   lengthscale: 0.680   noise: 1.934
# Iter 23/100 - Loss: 3.149   lengthscale: 0.677   noise: 1.987
# Iter 24/100 - Loss: 3.122   lengthscale: 0.673   noise: 2.038
# Iter 25/100 - Loss: 3.098   lengthscale: 0.670   noise: 2.088
# Iter 26/100 - Loss: 3.076   lengthscale: 0.666   noise: 2.137
# Iter 27/100 - Loss: 3.055   lengthscale: 0.663   noise: 2.184
# Iter 28/100 - Loss: 3.037   lengthscale: 0.661   noise: 2.230
# Iter 29/100 - Loss: 3.019   lengthscale: 0.660   noise: 2.275
# Iter 30/100 - Loss: 3.003   lengthscale: 0.660   noise: 2.318
# Iter 31/100 - Loss: 2.989   lengthscale: 0.661   noise: 2.360
# Iter 32/100 - Loss: 2.975   lengthscale: 0.664   noise: 2.401
# Iter 33/100 - Loss: 2.962   lengthscale: 0.668   noise: 2.441
# Iter 34/100 - Loss: 2.950   lengthscale: 0.672   noise: 2.479
# Iter 35/100 - Loss: 2.939   lengthscale: 0.677   noise: 2.516
# Iter 36/100 - Loss: 2.929   lengthscale: 0.683   noise: 2.552
# Iter 37/100 - Loss: 2.920   lengthscale: 0.690   noise: 2.587
# Iter 38/100 - Loss: 2.911   lengthscale: 0.696   noise: 2.621
# Iter 39/100 - Loss: 2.902   lengthscale: 0.702   noise: 2.654
# Iter 40/100 - Loss: 2.894   lengthscale: 0.707   noise: 2.687
# Iter 41/100 - Loss: 2.887   lengthscale: 0.712   noise: 2.718
# Iter 42/100 - Loss: 2.880   lengthscale: 0.716   noise: 2.748
# Iter 43/100 - Loss: 2.873   lengthscale: 0.719   noise: 2.778
# Iter 44/100 - Loss: 2.867   lengthscale: 0.721   noise: 2.806
# Iter 45/100 - Loss: 2.861   lengthscale: 0.723   noise: 2.834
# Iter 46/100 - Loss: 2.855   lengthscale: 0.723   noise: 2.862
# Iter 47/100 - Loss: 2.850   lengthscale: 0.723   noise: 2.888
# Iter 48/100 - Loss: 2.845   lengthscale: 0.722   noise: 2.914
# Iter 49/100 - Loss: 2.840   lengthscale: 0.721   noise: 2.940
# Iter 50/100 - Loss: 2.835   lengthscale: 0.720   noise: 2.964
# Iter 51/100 - Loss: 2.831   lengthscale: 0.718   noise: 2.989
# Iter 52/100 - Loss: 2.827   lengthscale: 0.717   noise: 3.012
# Iter 53/100 - Loss: 2.823   lengthscale: 0.717   noise: 3.035
# Iter 54/100 - Loss: 2.819   lengthscale: 0.717   noise: 3.058
# Iter 55/100 - Loss: 2.815   lengthscale: 0.717   noise: 3.080
# Iter 56/100 - Loss: 2.812   lengthscale: 0.718   noise: 3.102
# Iter 57/100 - Loss: 2.808   lengthscale: 0.720   noise: 3.123
# Iter 58/100 - Loss: 2.805   lengthscale: 0.721   noise: 3.144
# Iter 59/100 - Loss: 2.802   lengthscale: 0.724   noise: 3.164
# Iter 60/100 - Loss: 2.799   lengthscale: 0.726   noise: 3.184
# Iter 61/100 - Loss: 2.796   lengthscale: 0.729   noise: 3.204
# Iter 62/100 - Loss: 2.793   lengthscale: 0.732   noise: 3.223
# Iter 63/100 - Loss: 2.791   lengthscale: 0.734   noise: 3.242
# Iter 64/100 - Loss: 2.788   lengthscale: 0.737   noise: 3.261
# Iter 65/100 - Loss: 2.785   lengthscale: 0.739   noise: 3.279
# Iter 66/100 - Loss: 2.783   lengthscale: 0.741   noise: 3.298
# Iter 67/100 - Loss: 2.781   lengthscale: 0.743   noise: 3.316
# Iter 68/100 - Loss: 2.778   lengthscale: 0.744   noise: 3.333
# Iter 69/100 - Loss: 2.776   lengthscale: 0.746   noise: 3.350
# Iter 70/100 - Loss: 2.774   lengthscale: 0.746   noise: 3.368
# Iter 71/100 - Loss: 2.772   lengthscale: 0.747   noise: 3.384
# Iter 72/100 - Loss: 2.770   lengthscale: 0.748   noise: 3.401
# Iter 73/100 - Loss: 2.768   lengthscale: 0.748   noise: 3.418
# Iter 74/100 - Loss: 2.766   lengthscale: 0.748   noise: 3.434
# Iter 75/100 - Loss: 2.764   lengthscale: 0.749   noise: 3.450
# Iter 76/100 - Loss: 2.762   lengthscale: 0.749   noise: 3.466
# Iter 77/100 - Loss: 2.760   lengthscale: 0.750   noise: 3.481
# Iter 78/100 - Loss: 2.759   lengthscale: 0.750   noise: 3.497
# Iter 79/100 - Loss: 2.757   lengthscale: 0.751   noise: 3.512
# Iter 80/100 - Loss: 2.755   lengthscale: 0.752   noise: 3.527
# Iter 81/100 - Loss: 2.754   lengthscale: 0.753   noise: 3.542
# Iter 82/100 - Loss: 2.752   lengthscale: 0.754   noise: 3.557
# Iter 83/100 - Loss: 2.751   lengthscale: 0.755   noise: 3.572
# Iter 84/100 - Loss: 2.749   lengthscale: 0.756   noise: 3.586
# Iter 85/100 - Loss: 2.748   lengthscale: 0.757   noise: 3.600
# Iter 86/100 - Loss: 2.746   lengthscale: 0.759   noise: 3.614
# Iter 87/100 - Loss: 2.745   lengthscale: 0.760   noise: 3.629
# Iter 88/100 - Loss: 2.743   lengthscale: 0.761   noise: 3.642
# Iter 89/100 - Loss: 2.742   lengthscale: 0.763   noise: 3.656
# Iter 90/100 - Loss: 2.741   lengthscale: 0.764   noise: 3.670
# Iter 91/100 - Loss: 2.740   lengthscale: 0.765   noise: 3.683
# Iter 92/100 - Loss: 2.738   lengthscale: 0.766   noise: 3.697
# Iter 93/100 - Loss: 2.737   lengthscale: 0.767   noise: 3.710
# Iter 94/100 - Loss: 2.736   lengthscale: 0.768   noise: 3.723
# Iter 95/100 - Loss: 2.735   lengthscale: 0.769   noise: 3.736
# Iter 96/100 - Loss: 2.734   lengthscale: 0.770   noise: 3.749
# Iter 97/100 - Loss: 2.732   lengthscale: 0.770   noise: 3.762
# Iter 98/100 - Loss: 2.731   lengthscale: 0.771   noise: 3.775
# Iter 99/100 - Loss: 2.730   lengthscale: 0.772   noise: 3.787
# Iter 100/100 - Loss: 2.729   lengthscale: 0.773   noise: 3.800
# (100000, 13)
# Iter 1/100 - Loss: 4.657   lengthscale: 0.693   noise: 0.693
# Iter 2/100 - Loss: 4.436   lengthscale: 0.744   noise: 0.744
# Iter 3/100 - Loss: 4.240   lengthscale: 0.797   noise: 0.798
# Iter 4/100 - Loss: 4.068   lengthscale: 0.850   noise: 0.854
# Iter 5/100 - Loss: 3.917   lengthscale: 0.901   noise: 0.911
# Iter 6/100 - Loss: 3.783   lengthscale: 0.945   noise: 0.970
# Iter 7/100 - Loss: 3.665   lengthscale: 0.981   noise: 1.030
# Iter 8/100 - Loss: 3.559   lengthscale: 1.007   noise: 1.092
# Iter 9/100 - Loss: 3.465   lengthscale: 1.024   noise: 1.154
# Iter 10/100 - Loss: 3.381   lengthscale: 1.034   noise: 1.217
# Iter 11/100 - Loss: 3.306   lengthscale: 1.036   noise: 1.280
# Iter 12/100 - Loss: 3.239   lengthscale: 1.033   noise: 1.343
# Iter 13/100 - Loss: 3.179   lengthscale: 1.027   noise: 1.406
# Iter 14/100 - Loss: 3.125   lengthscale: 1.018   noise: 1.468
# Iter 15/100 - Loss: 3.078   lengthscale: 1.007   noise: 1.530
# Iter 16/100 - Loss: 3.035   lengthscale: 0.996   noise: 1.591
# Iter 17/100 - Loss: 2.997   lengthscale: 0.984   noise: 1.651
# Iter 18/100 - Loss: 2.962   lengthscale: 0.973   noise: 1.709
# Iter 19/100 - Loss: 2.932   lengthscale: 0.963   noise: 1.767
# Iter 20/100 - Loss: 2.904   lengthscale: 0.954   noise: 1.823
# Iter 21/100 - Loss: 2.879   lengthscale: 0.946   noise: 1.877
# Iter 22/100 - Loss: 2.857   lengthscale: 0.941   noise: 1.930
# Iter 23/100 - Loss: 2.836   lengthscale: 0.938   noise: 1.982
# Iter 24/100 - Loss: 2.818   lengthscale: 0.936   noise: 2.032
# Iter 25/100 - Loss: 2.801   lengthscale: 0.937   noise: 2.081
# Iter 26/100 - Loss: 2.786   lengthscale: 0.940   noise: 2.128
# Iter 27/100 - Loss: 2.772   lengthscale: 0.944   noise: 2.174
# Iter 28/100 - Loss: 2.759   lengthscale: 0.951   noise: 2.218
# Iter 29/100 - Loss: 2.747   lengthscale: 0.959   noise: 2.261
# Iter 30/100 - Loss: 2.736   lengthscale: 0.968   noise: 2.302
# Iter 31/100 - Loss: 2.726   lengthscale: 0.978   noise: 2.342
# Iter 32/100 - Loss: 2.717   lengthscale: 0.989   noise: 2.380
# Iter 33/100 - Loss: 2.708   lengthscale: 1.000   noise: 2.418
# Iter 34/100 - Loss: 2.700   lengthscale: 1.011   noise: 2.454
# Iter 35/100 - Loss: 2.693   lengthscale: 1.022   noise: 2.489
# Iter 36/100 - Loss: 2.686   lengthscale: 1.033   noise: 2.522
# Iter 37/100 - Loss: 2.680   lengthscale: 1.043   noise: 2.555
# Iter 38/100 - Loss: 2.674   lengthscale: 1.053   noise: 2.587
# Iter 39/100 - Loss: 2.668   lengthscale: 1.061   noise: 2.617
# Iter 40/100 - Loss: 2.663   lengthscale: 1.069   noise: 2.647
# Iter 41/100 - Loss: 2.658   lengthscale: 1.077   noise: 2.675
# Iter 42/100 - Loss: 2.654   lengthscale: 1.083   noise: 2.703
# Iter 43/100 - Loss: 2.650   lengthscale: 1.089   noise: 2.730
# Iter 44/100 - Loss: 2.646   lengthscale: 1.093   noise: 2.756
# Iter 45/100 - Loss: 2.642   lengthscale: 1.097   noise: 2.782
# Iter 46/100 - Loss: 2.638   lengthscale: 1.101   noise: 2.806
# Iter 47/100 - Loss: 2.635   lengthscale: 1.103   noise: 2.830
# Iter 48/100 - Loss: 2.632   lengthscale: 1.105   noise: 2.853
# Iter 49/100 - Loss: 2.629   lengthscale: 1.107   noise: 2.876
# Iter 50/100 - Loss: 2.626   lengthscale: 1.108   noise: 2.898
# Iter 51/100 - Loss: 2.623   lengthscale: 1.109   noise: 2.920
# Iter 52/100 - Loss: 2.621   lengthscale: 1.109   noise: 2.941
# Iter 53/100 - Loss: 2.618   lengthscale: 1.109   noise: 2.961
# Iter 54/100 - Loss: 2.616   lengthscale: 1.109   noise: 2.981
# Iter 55/100 - Loss: 2.614   lengthscale: 1.109   noise: 3.000
# Iter 56/100 - Loss: 2.611   lengthscale: 1.109   noise: 3.019
# Iter 57/100 - Loss: 2.609   lengthscale: 1.109   noise: 3.038
# Iter 58/100 - Loss: 2.607   lengthscale: 1.109   noise: 3.056
# Iter 59/100 - Loss: 2.605   lengthscale: 1.109   noise: 3.073
# Iter 60/100 - Loss: 2.604   lengthscale: 1.110   noise: 3.091
# Iter 61/100 - Loss: 2.602   lengthscale: 1.111   noise: 3.107
# Iter 62/100 - Loss: 2.600   lengthscale: 1.112   noise: 3.124
# Iter 63/100 - Loss: 2.599   lengthscale: 1.113   noise: 3.140
# Iter 64/100 - Loss: 2.597   lengthscale: 1.114   noise: 3.156
# Iter 65/100 - Loss: 2.596   lengthscale: 1.116   noise: 3.172
# Iter 66/100 - Loss: 2.594   lengthscale: 1.118   noise: 3.187
# Iter 67/100 - Loss: 2.593   lengthscale: 1.121   noise: 3.202
# Iter 68/100 - Loss: 2.591   lengthscale: 1.123   noise: 3.217
# Iter 69/100 - Loss: 2.590   lengthscale: 1.126   noise: 3.231
# Iter 70/100 - Loss: 2.589   lengthscale: 1.129   noise: 3.245
# Iter 71/100 - Loss: 2.588   lengthscale: 1.132   noise: 3.259
# Iter 72/100 - Loss: 2.587   lengthscale: 1.135   noise: 3.273
# Iter 73/100 - Loss: 2.585   lengthscale: 1.138   noise: 3.287
# Iter 74/100 - Loss: 2.584   lengthscale: 1.142   noise: 3.300
# Iter 75/100 - Loss: 2.583   lengthscale: 1.145   noise: 3.313
# Iter 76/100 - Loss: 2.582   lengthscale: 1.148   noise: 3.326
# Iter 77/100 - Loss: 2.581   lengthscale: 1.151   noise: 3.339
# Iter 78/100 - Loss: 2.580   lengthscale: 1.154   noise: 3.351
# Iter 79/100 - Loss: 2.579   lengthscale: 1.157   noise: 3.364
# Iter 80/100 - Loss: 2.578   lengthscale: 1.160   noise: 3.376
# Iter 81/100 - Loss: 2.577   lengthscale: 1.162   noise: 3.388
# Iter 82/100 - Loss: 2.576   lengthscale: 1.165   noise: 3.400
# Iter 83/100 - Loss: 2.576   lengthscale: 1.167   noise: 3.411
# Iter 84/100 - Loss: 2.575   lengthscale: 1.170   noise: 3.423
# Iter 85/100 - Loss: 2.574   lengthscale: 1.172   noise: 3.434
# Iter 86/100 - Loss: 2.573   lengthscale: 1.174   noise: 3.446
# Iter 87/100 - Loss: 2.572   lengthscale: 1.176   noise: 3.457
# Iter 88/100 - Loss: 2.572   lengthscale: 1.178   noise: 3.468
# Iter 89/100 - Loss: 2.571   lengthscale: 1.180   noise: 3.479
# Iter 90/100 - Loss: 2.570   lengthscale: 1.182   noise: 3.489
# Iter 91/100 - Loss: 2.569   lengthscale: 1.184   noise: 3.500
# Iter 92/100 - Loss: 2.569   lengthscale: 1.185   noise: 3.510
# Iter 93/100 - Loss: 2.568   lengthscale: 1.187   noise: 3.521
# Iter 94/100 - Loss: 2.567   lengthscale: 1.189   noise: 3.531
# Iter 95/100 - Loss: 2.567   lengthscale: 1.190   noise: 3.541
# Iter 96/100 - Loss: 2.566   lengthscale: 1.192   noise: 3.551
# Iter 97/100 - Loss: 2.566   lengthscale: 1.193   noise: 3.561
# Iter 98/100 - Loss: 2.565   lengthscale: 1.195   noise: 3.571
# Iter 99/100 - Loss: 2.564   lengthscale: 1.196   noise: 3.580
# Iter 100/100 - Loss: 2.564   lengthscale: 1.198   noise: 3.590
# (100000, 16)
# Iter 1/100 - Loss: 3.999   lengthscale: 0.693   noise: 0.693
# Iter 2/100 - Loss: 3.827   lengthscale: 0.744   noise: 0.744
# Iter 3/100 - Loss: 3.676   lengthscale: 0.797   noise: 0.798
# Iter 4/100 - Loss: 3.542   lengthscale: 0.850   noise: 0.854
# Iter 5/100 - Loss: 3.424   lengthscale: 0.900   noise: 0.911
# Iter 6/100 - Loss: 3.320   lengthscale: 0.945   noise: 0.970
# Iter 7/100 - Loss: 3.228   lengthscale: 0.980   noise: 1.030
# Iter 8/100 - Loss: 3.147   lengthscale: 1.006   noise: 1.091
# Iter 9/100 - Loss: 3.075   lengthscale: 1.022   noise: 1.153
# Iter 10/100 - Loss: 3.011   lengthscale: 1.029   noise: 1.216
# Iter 11/100 - Loss: 2.955   lengthscale: 1.030   noise: 1.279
# Iter 12/100 - Loss: 2.904   lengthscale: 1.025   noise: 1.341
# Iter 13/100 - Loss: 2.859   lengthscale: 1.017   noise: 1.403
# Iter 14/100 - Loss: 2.820   lengthscale: 1.006   noise: 1.465
# Iter 15/100 - Loss: 2.785   lengthscale: 0.995   noise: 1.526
# Iter 16/100 - Loss: 2.754   lengthscale: 0.984   noise: 1.586
# Iter 17/100 - Loss: 2.726   lengthscale: 0.974   noise: 1.644
# Iter 18/100 - Loss: 2.702   lengthscale: 0.966   noise: 1.702
# Iter 19/100 - Loss: 2.680   lengthscale: 0.960   noise: 1.758
# Iter 20/100 - Loss: 2.660   lengthscale: 0.957   noise: 1.813
# Iter 21/100 - Loss: 2.643   lengthscale: 0.956   noise: 1.866
# Iter 22/100 - Loss: 2.627   lengthscale: 0.958   noise: 1.917
# Iter 23/100 - Loss: 2.613   lengthscale: 0.963   noise: 1.967
# Iter 24/100 - Loss: 2.600   lengthscale: 0.969   noise: 2.016
# Iter 25/100 - Loss: 2.588   lengthscale: 0.978   noise: 2.062
# Iter 26/100 - Loss: 2.578   lengthscale: 0.989   noise: 2.108
# Iter 27/100 - Loss: 2.568   lengthscale: 1.001   noise: 2.151
# Iter 28/100 - Loss: 2.559   lengthscale: 1.015   noise: 2.193
# Iter 29/100 - Loss: 2.552   lengthscale: 1.029   noise: 2.234
# Iter 30/100 - Loss: 2.544   lengthscale: 1.044   noise: 2.273
# Iter 31/100 - Loss: 2.538   lengthscale: 1.059   noise: 2.311
# Iter 32/100 - Loss: 2.532   lengthscale: 1.074   noise: 2.347
# Iter 33/100 - Loss: 2.526   lengthscale: 1.089   noise: 2.383
# Iter 34/100 - Loss: 2.521   lengthscale: 1.103   noise: 2.416
# Iter 35/100 - Loss: 2.516   lengthscale: 1.116   noise: 2.449
# Iter 36/100 - Loss: 2.512   lengthscale: 1.129   noise: 2.480
# Iter 37/100 - Loss: 2.508   lengthscale: 1.140   noise: 2.511
# Iter 38/100 - Loss: 2.505   lengthscale: 1.150   noise: 2.540
# Iter 39/100 - Loss: 2.501   lengthscale: 1.159   noise: 2.568
# Iter 40/100 - Loss: 2.498   lengthscale: 1.167   noise: 2.595
# Iter 41/100 - Loss: 2.495   lengthscale: 1.174   noise: 2.622
# Iter 42/100 - Loss: 2.492   lengthscale: 1.179   noise: 2.647
# Iter 43/100 - Loss: 2.490   lengthscale: 1.184   noise: 2.672
# Iter 44/100 - Loss: 2.487   lengthscale: 1.188   noise: 2.695
# Iter 45/100 - Loss: 2.485   lengthscale: 1.191   noise: 2.718
# Iter 46/100 - Loss: 2.483   lengthscale: 1.194   noise: 2.741
# Iter 47/100 - Loss: 2.481   lengthscale: 1.196   noise: 2.762
# Iter 48/100 - Loss: 2.479   lengthscale: 1.198   noise: 2.783
# Iter 49/100 - Loss: 2.477   lengthscale: 1.199   noise: 2.803
# Iter 50/100 - Loss: 2.476   lengthscale: 1.201   noise: 2.823
# Iter 51/100 - Loss: 2.474   lengthscale: 1.202   noise: 2.842
# Iter 52/100 - Loss: 2.473   lengthscale: 1.203   noise: 2.860
# Iter 53/100 - Loss: 2.471   lengthscale: 1.205   noise: 2.878
# Iter 54/100 - Loss: 2.470   lengthscale: 1.207   noise: 2.895
# Iter 55/100 - Loss: 2.469   lengthscale: 1.209   noise: 2.912
# Iter 56/100 - Loss: 2.468   lengthscale: 1.211   noise: 2.929
# Iter 57/100 - Loss: 2.466   lengthscale: 1.214   noise: 2.945
# Iter 58/100 - Loss: 2.465   lengthscale: 1.217   noise: 2.960
# Iter 59/100 - Loss: 2.464   lengthscale: 1.220   noise: 2.975
# Iter 60/100 - Loss: 2.463   lengthscale: 1.224   noise: 2.990
# Iter 61/100 - Loss: 2.462   lengthscale: 1.228   noise: 3.004
# Iter 62/100 - Loss: 2.462   lengthscale: 1.232   noise: 3.018
# Iter 63/100 - Loss: 2.461   lengthscale: 1.237   noise: 3.032
# Iter 64/100 - Loss: 2.460   lengthscale: 1.241   noise: 3.046
# Iter 65/100 - Loss: 2.459   lengthscale: 1.246   noise: 3.059
# Iter 66/100 - Loss: 2.458   lengthscale: 1.251   noise: 3.071
# Iter 67/100 - Loss: 2.458   lengthscale: 1.256   noise: 3.084
# Iter 68/100 - Loss: 2.457   lengthscale: 1.262   noise: 3.096
# Iter 69/100 - Loss: 2.456   lengthscale: 1.267   noise: 3.108
# Iter 70/100 - Loss: 2.456   lengthscale: 1.272   noise: 3.120
# Iter 71/100 - Loss: 2.455   lengthscale: 1.277   noise: 3.131
# Iter 72/100 - Loss: 2.454   lengthscale: 1.282   noise: 3.143
# Iter 73/100 - Loss: 2.454   lengthscale: 1.287   noise: 3.154
# Iter 74/100 - Loss: 2.453   lengthscale: 1.291   noise: 3.165
# Iter 75/100 - Loss: 2.453   lengthscale: 1.296   noise: 3.175
# Iter 76/100 - Loss: 2.452   lengthscale: 1.300   noise: 3.186
# Iter 77/100 - Loss: 2.452   lengthscale: 1.304   noise: 3.196
# Iter 78/100 - Loss: 2.451   lengthscale: 1.308   noise: 3.207
# Iter 79/100 - Loss: 2.451   lengthscale: 1.312   noise: 3.217
# Iter 80/100 - Loss: 2.450   lengthscale: 1.316   noise: 3.226
# Iter 81/100 - Loss: 2.450   lengthscale: 1.319   noise: 3.236
# Iter 82/100 - Loss: 2.449   lengthscale: 1.322   noise: 3.246
# Iter 83/100 - Loss: 2.449   lengthscale: 1.325   noise: 3.255
# Iter 84/100 - Loss: 2.448   lengthscale: 1.329   noise: 3.264
# Iter 85/100 - Loss: 2.448   lengthscale: 1.331   noise: 3.273
# Iter 86/100 - Loss: 2.448   lengthscale: 1.334   noise: 3.282
# Iter 87/100 - Loss: 2.447   lengthscale: 1.337   noise: 3.291
# Iter 88/100 - Loss: 2.447   lengthscale: 1.340   noise: 3.300
# Iter 89/100 - Loss: 2.446   lengthscale: 1.343   noise: 3.308
# Iter 90/100 - Loss: 2.446   lengthscale: 1.345   noise: 3.317
# Iter 91/100 - Loss: 2.446   lengthscale: 1.348   noise: 3.325
# Iter 92/100 - Loss: 2.445   lengthscale: 1.351   noise: 3.333
# Iter 93/100 - Loss: 2.445   lengthscale: 1.354   noise: 3.342
# Iter 94/100 - Loss: 2.445   lengthscale: 1.356   noise: 3.350
# Iter 95/100 - Loss: 2.445   lengthscale: 1.359   noise: 3.357
# Iter 96/100 - Loss: 2.444   lengthscale: 1.362   noise: 3.365
# Iter 97/100 - Loss: 2.444   lengthscale: 1.365   noise: 3.373
# Iter 98/100 - Loss: 2.444   lengthscale: 1.368   noise: 3.380
# Iter 99/100 - Loss: 2.443   lengthscale: 1.371   noise: 3.388
# Iter 100/100 - Loss: 2.443   lengthscale: 1.374   noise: 3.395
# (100000, 19)
# Iter 1/100 - Loss: 2.878   lengthscale: 0.693   noise: 0.693
# Iter 2/100 - Loss: 2.781   lengthscale: 0.744   noise: 0.744
# Iter 3/100 - Loss: 2.698   lengthscale: 0.798   noise: 0.798
# Iter 4/100 - Loss: 2.626   lengthscale: 0.853   noise: 0.853
# Iter 5/100 - Loss: 2.563   lengthscale: 0.908   noise: 0.910
# Iter 6/100 - Loss: 2.510   lengthscale: 0.963   noise: 0.969
# Iter 7/100 - Loss: 2.464   lengthscale: 1.016   noise: 1.028
# Iter 8/100 - Loss: 2.425   lengthscale: 1.067   noise: 1.088
# Iter 9/100 - Loss: 2.392   lengthscale: 1.113   noise: 1.149
# Iter 10/100 - Loss: 2.363   lengthscale: 1.156   noise: 1.209
# Iter 11/100 - Loss: 2.338   lengthscale: 1.194   noise: 1.269
# Iter 12/100 - Loss: 2.317   lengthscale: 1.227   noise: 1.329
# Iter 13/100 - Loss: 2.298   lengthscale: 1.255   noise: 1.388
# Iter 14/100 - Loss: 2.282   lengthscale: 1.279   noise: 1.446
# Iter 15/100 - Loss: 2.269   lengthscale: 1.299   noise: 1.503
# Iter 16/100 - Loss: 2.257   lengthscale: 1.316   noise: 1.558
# Iter 17/100 - Loss: 2.247   lengthscale: 1.329   noise: 1.612
# Iter 18/100 - Loss: 2.238   lengthscale: 1.340   noise: 1.664
# Iter 19/100 - Loss: 2.231   lengthscale: 1.349   noise: 1.714
# Iter 20/100 - Loss: 2.224   lengthscale: 1.356   noise: 1.762
# Iter 21/100 - Loss: 2.219   lengthscale: 1.362   noise: 1.809
# Iter 22/100 - Loss: 2.214   lengthscale: 1.367   noise: 1.853
# Iter 23/100 - Loss: 2.210   lengthscale: 1.371   noise: 1.895
# Iter 24/100 - Loss: 2.207   lengthscale: 1.375   noise: 1.936
# Iter 25/100 - Loss: 2.204   lengthscale: 1.378   noise: 1.974
# Iter 26/100 - Loss: 2.201   lengthscale: 1.382   noise: 2.010
# Iter 27/100 - Loss: 2.199   lengthscale: 1.386   noise: 2.044
# Iter 28/100 - Loss: 2.197   lengthscale: 1.390   noise: 2.077
# Iter 29/100 - Loss: 2.195   lengthscale: 1.395   noise: 2.107
# Iter 30/100 - Loss: 2.194   lengthscale: 1.401   noise: 2.136
# Iter 31/100 - Loss: 2.192   lengthscale: 1.407   noise: 2.163
# Iter 32/100 - Loss: 2.191   lengthscale: 1.414   noise: 2.188
# Iter 33/100 - Loss: 2.190   lengthscale: 1.422   noise: 2.211
# Iter 34/100 - Loss: 2.190   lengthscale: 1.430   noise: 2.233
# Iter 35/100 - Loss: 2.189   lengthscale: 1.439   noise: 2.253
# Iter 36/100 - Loss: 2.188   lengthscale: 1.449   noise: 2.272
# Iter 37/100 - Loss: 2.188   lengthscale: 1.460   noise: 2.289
# Iter 38/100 - Loss: 2.187   lengthscale: 1.472   noise: 2.306
# Iter 39/100 - Loss: 2.187   lengthscale: 1.484   noise: 2.320
# Iter 40/100 - Loss: 2.186   lengthscale: 1.496   noise: 2.334
# Iter 41/100 - Loss: 2.186   lengthscale: 1.510   noise: 2.347
# Iter 42/100 - Loss: 2.185   lengthscale: 1.523   noise: 2.358
# Iter 43/100 - Loss: 2.185   lengthscale: 1.537   noise: 2.369
# Iter 44/100 - Loss: 2.185   lengthscale: 1.551   noise: 2.378
# Iter 45/100 - Loss: 2.185   lengthscale: 1.566   noise: 2.387
# Iter 46/100 - Loss: 2.184   lengthscale: 1.580   noise: 2.395
# Iter 47/100 - Loss: 2.184   lengthscale: 1.595   noise: 2.402
# Iter 48/100 - Loss: 2.184   lengthscale: 1.610   noise: 2.408
# Iter 49/100 - Loss: 2.184   lengthscale: 1.624   noise: 2.414
# Iter 50/100 - Loss: 2.183   lengthscale: 1.639   noise: 2.419
# Iter 51/100 - Loss: 2.183   lengthscale: 1.653   noise: 2.423
# Iter 52/100 - Loss: 2.183   lengthscale: 1.667   noise: 2.427
# Iter 53/100 - Loss: 2.183   lengthscale: 1.681   noise: 2.430
# Iter 54/100 - Loss: 2.183   lengthscale: 1.695   noise: 2.433
# Iter 55/100 - Loss: 2.183   lengthscale: 1.708   noise: 2.435
# Iter 56/100 - Loss: 2.183   lengthscale: 1.720   noise: 2.437
# Iter 57/100 - Loss: 2.182   lengthscale: 1.732   noise: 2.439
# Iter 58/100 - Loss: 2.182   lengthscale: 1.744   noise: 2.440
# Iter 59/100 - Loss: 2.182   lengthscale: 1.755   noise: 2.441
# Iter 60/100 - Loss: 2.182   lengthscale: 1.766   noise: 2.442
# Iter 61/100 - Loss: 2.182   lengthscale: 1.776   noise: 2.442
# Iter 62/100 - Loss: 2.182   lengthscale: 1.786   noise: 2.442
# Iter 63/100 - Loss: 2.182   lengthscale: 1.795   noise: 2.442
# Iter 64/100 - Loss: 2.182   lengthscale: 1.803   noise: 2.442
# Iter 65/100 - Loss: 2.182   lengthscale: 1.811   noise: 2.441
# Iter 66/100 - Loss: 2.182   lengthscale: 1.818   noise: 2.441
# Iter 67/100 - Loss: 2.182   lengthscale: 1.825   noise: 2.440
# Iter 68/100 - Loss: 2.181   lengthscale: 1.832   noise: 2.439
# Iter 69/100 - Loss: 2.181   lengthscale: 1.837   noise: 2.438
# Iter 70/100 - Loss: 2.181   lengthscale: 1.843   noise: 2.436
# Iter 71/100 - Loss: 2.181   lengthscale: 1.848   noise: 2.435
# Iter 72/100 - Loss: 2.181   lengthscale: 1.852   noise: 2.433
# Iter 73/100 - Loss: 2.181   lengthscale: 1.856   noise: 2.431
# Iter 74/100 - Loss: 2.181   lengthscale: 1.859   noise: 2.429
# Iter 75/100 - Loss: 2.181   lengthscale: 1.862   noise: 2.427
# Iter 76/100 - Loss: 2.181   lengthscale: 1.865   noise: 2.425
# Iter 77/100 - Loss: 2.181   lengthscale: 1.867   noise: 2.423
# Iter 78/100 - Loss: 2.181   lengthscale: 1.869   noise: 2.421
# Iter 79/100 - Loss: 2.181   lengthscale: 1.871   noise: 2.419
# Iter 80/100 - Loss: 2.181   lengthscale: 1.872   noise: 2.416
# Iter 81/100 - Loss: 2.180   lengthscale: 1.873   noise: 2.414
# Iter 82/100 - Loss: 2.180   lengthscale: 1.874   noise: 2.411
# Iter 83/100 - Loss: 2.180   lengthscale: 1.875   noise: 2.408
# Iter 84/100 - Loss: 2.180   lengthscale: 1.875   noise: 2.406
# Iter 85/100 - Loss: 2.180   lengthscale: 1.875   noise: 2.403
# Iter 86/100 - Loss: 2.180   lengthscale: 1.875   noise: 2.400
# Iter 87/100 - Loss: 2.180   lengthscale: 1.875   noise: 2.397
# Iter 88/100 - Loss: 2.180   lengthscale: 1.875   noise: 2.394
# Iter 89/100 - Loss: 2.180   lengthscale: 1.875   noise: 2.391
# Iter 90/100 - Loss: 2.180   lengthscale: 1.874   noise: 2.388
# Iter 91/100 - Loss: 2.180   lengthscale: 1.874   noise: 2.384
# Iter 92/100 - Loss: 2.180   lengthscale: 1.873   noise: 2.381
# Iter 93/100 - Loss: 2.180   lengthscale: 1.872   noise: 2.377
# Iter 94/100 - Loss: 2.180   lengthscale: 1.872   noise: 2.374
# Iter 95/100 - Loss: 2.180   lengthscale: 1.871   noise: 2.370
# Iter 96/100 - Loss: 2.179   lengthscale: 1.870   noise: 2.367
# Iter 97/100 - Loss: 2.179   lengthscale: 1.869   noise: 2.363
# Iter 98/100 - Loss: 2.179   lengthscale: 1.868   noise: 2.359
# Iter 99/100 - Loss: 2.179   lengthscale: 1.868   noise: 2.355
# Iter 100/100 - Loss: 2.179   lengthscale: 1.867   noise: 2.352
# (100000, 22)
# Iter 1/100 - Loss: 2.641   lengthscale: 0.693   noise: 0.693
# Iter 2/100 - Loss: 2.566   lengthscale: 0.644   noise: 0.744
# Iter 3/100 - Loss: 2.504   lengthscale: 0.611   noise: 0.798
# Iter 4/100 - Loss: 2.449   lengthscale: 0.598   noise: 0.853
# Iter 5/100 - Loss: 2.401   lengthscale: 0.599   noise: 0.910
# Iter 6/100 - Loss: 2.360   lengthscale: 0.606   noise: 0.968
# Iter 7/100 - Loss: 2.326   lengthscale: 0.615   noise: 1.027
# Iter 8/100 - Loss: 2.296   lengthscale: 0.626   noise: 1.087
# Iter 9/100 - Loss: 2.271   lengthscale: 0.637   noise: 1.146
# Iter 10/100 - Loss: 2.249   lengthscale: 0.648   noise: 1.206
# Iter 11/100 - Loss: 2.230   lengthscale: 0.659   noise: 1.265
# Iter 12/100 - Loss: 2.215   lengthscale: 0.671   noise: 1.323
# Iter 13/100 - Loss: 2.202   lengthscale: 0.684   noise: 1.380
# Iter 14/100 - Loss: 2.191   lengthscale: 0.698   noise: 1.435
# Iter 15/100 - Loss: 2.182   lengthscale: 0.714   noise: 1.489
# Iter 16/100 - Loss: 2.174   lengthscale: 0.731   noise: 1.541
# Iter 17/100 - Loss: 2.168   lengthscale: 0.748   noise: 1.591
# Iter 18/100 - Loss: 2.163   lengthscale: 0.765   noise: 1.639
# Iter 19/100 - Loss: 2.158   lengthscale: 0.780   noise: 1.685
# Iter 20/100 - Loss: 2.155   lengthscale: 0.793   noise: 1.729
# Iter 21/100 - Loss: 2.152   lengthscale: 0.803   noise: 1.771
# Iter 22/100 - Loss: 2.149   lengthscale: 0.811   noise: 1.810
# Iter 23/100 - Loss: 2.147   lengthscale: 0.816   noise: 1.847
# Iter 24/100 - Loss: 2.146   lengthscale: 0.819   noise: 1.882
# Iter 25/100 - Loss: 2.144   lengthscale: 0.820   noise: 1.915
# Iter 26/100 - Loss: 2.143   lengthscale: 0.820   noise: 1.946
# Iter 27/100 - Loss: 2.142   lengthscale: 0.820   noise: 1.974
# Iter 28/100 - Loss: 2.142   lengthscale: 0.820   noise: 2.001
# Iter 29/100 - Loss: 2.141   lengthscale: 0.820   noise: 2.026
# Iter 30/100 - Loss: 2.141   lengthscale: 0.822   noise: 2.048
# Iter 31/100 - Loss: 2.140   lengthscale: 0.826   noise: 2.069
# Iter 32/100 - Loss: 2.140   lengthscale: 0.831   noise: 2.088
# Iter 33/100 - Loss: 2.140   lengthscale: 0.838   noise: 2.105
# Iter 34/100 - Loss: 2.140   lengthscale: 0.846   noise: 2.121
# Iter 35/100 - Loss: 2.140   lengthscale: 0.856   noise: 2.135
# Iter 36/100 - Loss: 2.140   lengthscale: 0.866   noise: 2.148
# Iter 37/100 - Loss: 2.140   lengthscale: 0.876   noise: 2.159
# Iter 38/100 - Loss: 2.140   lengthscale: 0.887   noise: 2.169
# Iter 39/100 - Loss: 2.139   lengthscale: 0.897   noise: 2.178
# Iter 40/100 - Loss: 2.139   lengthscale: 0.906   noise: 2.185
# Iter 41/100 - Loss: 2.139   lengthscale: 0.914   noise: 2.192
# Iter 42/100 - Loss: 2.139   lengthscale: 0.921   noise: 2.197
# Iter 43/100 - Loss: 2.139   lengthscale: 0.927   noise: 2.202
# Iter 44/100 - Loss: 2.139   lengthscale: 0.931   noise: 2.205
# Iter 45/100 - Loss: 2.140   lengthscale: 0.935   noise: 2.208
# Iter 46/100 - Loss: 2.139   lengthscale: 0.938   noise: 2.210
# Iter 47/100 - Loss: 2.139   lengthscale: 0.940   noise: 2.211
# Iter 48/100 - Loss: 2.139   lengthscale: 0.941   noise: 2.211
# Iter 49/100 - Loss: 2.139   lengthscale: 0.942   noise: 2.211
# Iter 50/100 - Loss: 2.139   lengthscale: 0.943   noise: 2.210
# Iter 51/100 - Loss: 2.139   lengthscale: 0.944   noise: 2.209
# Iter 52/100 - Loss: 2.139   lengthscale: 0.944   noise: 2.207
# Iter 53/100 - Loss: 2.139   lengthscale: 0.945   noise: 2.205
# Iter 54/100 - Loss: 2.139   lengthscale: 0.945   noise: 2.202
# Iter 55/100 - Loss: 2.139   lengthscale: 0.946   noise: 2.198
# Iter 56/100 - Loss: 2.139   lengthscale: 0.946   noise: 2.195
# Iter 57/100 - Loss: 2.139   lengthscale: 0.945   noise: 2.190
# Iter 58/100 - Loss: 2.139   lengthscale: 0.945   noise: 2.186
# Iter 59/100 - Loss: 2.139   lengthscale: 0.944   noise: 2.181
# Iter 60/100 - Loss: 2.139   lengthscale: 0.943   noise: 2.176
# Iter 61/100 - Loss: 2.139   lengthscale: 0.941   noise: 2.171
# Iter 62/100 - Loss: 2.139   lengthscale: 0.939   noise: 2.166
# Iter 63/100 - Loss: 2.139   lengthscale: 0.937   noise: 2.160
# Iter 64/100 - Loss: 2.139   lengthscale: 0.935   noise: 2.154
# Iter 65/100 - Loss: 2.139   lengthscale: 0.933   noise: 2.148
# Iter 66/100 - Loss: 2.139   lengthscale: 0.932   noise: 2.142
# Iter 67/100 - Loss: 2.139   lengthscale: 0.930   noise: 2.135
# Iter 68/100 - Loss: 2.139   lengthscale: 0.929   noise: 2.129
# Iter 69/100 - Loss: 2.139   lengthscale: 0.929   noise: 2.122
# Iter 70/100 - Loss: 2.139   lengthscale: 0.928   noise: 2.115
# Iter 71/100 - Loss: 2.138   lengthscale: 0.928   noise: 2.109
# Iter 72/100 - Loss: 2.138   lengthscale: 0.928   noise: 2.102
# Iter 73/100 - Loss: 2.138   lengthscale: 0.928   noise: 2.095
# Iter 74/100 - Loss: 2.138   lengthscale: 0.928   noise: 2.088
# Iter 75/100 - Loss: 2.138   lengthscale: 0.929   noise: 2.081
# Iter 76/100 - Loss: 2.138   lengthscale: 0.928   noise: 2.074
# Iter 77/100 - Loss: 2.138   lengthscale: 0.928   noise: 2.067
# Iter 78/100 - Loss: 2.138   lengthscale: 0.927   noise: 2.060
# Iter 79/100 - Loss: 2.138   lengthscale: 0.926   noise: 2.053
# Iter 80/100 - Loss: 2.138   lengthscale: 0.925   noise: 2.045
# Iter 81/100 - Loss: 2.138   lengthscale: 0.924   noise: 2.038
# Iter 82/100 - Loss: 2.138   lengthscale: 0.923   noise: 2.031
# Iter 83/100 - Loss: 2.138   lengthscale: 0.921   noise: 2.024
# Iter 84/100 - Loss: 2.138   lengthscale: 0.920   noise: 2.017
# Iter 85/100 - Loss: 2.138   lengthscale: 0.919   noise: 2.010
# Iter 86/100 - Loss: 2.138   lengthscale: 0.918   noise: 2.003
# Iter 87/100 - Loss: 2.138   lengthscale: 0.917   noise: 1.997
# Iter 88/100 - Loss: 2.137   lengthscale: 0.916   noise: 1.990
# Iter 89/100 - Loss: 2.137   lengthscale: 0.915   noise: 1.983
# Iter 90/100 - Loss: 2.137   lengthscale: 0.914   noise: 1.976
# Iter 91/100 - Loss: 2.137   lengthscale: 0.914   noise: 1.969
# Iter 92/100 - Loss: 2.137   lengthscale: 0.913   noise: 1.963
# Iter 93/100 - Loss: 2.137   lengthscale: 0.912   noise: 1.956
# Iter 94/100 - Loss: 2.137   lengthscale: 0.912   noise: 1.949
# Iter 95/100 - Loss: 2.137   lengthscale: 0.911   noise: 1.943
# Iter 96/100 - Loss: 2.137   lengthscale: 0.911   noise: 1.936
# Iter 97/100 - Loss: 2.137   lengthscale: 0.910   noise: 1.930
# Iter 98/100 - Loss: 2.137   lengthscale: 0.910   noise: 1.923
# Iter 99/100 - Loss: 2.137   lengthscale: 0.909   noise: 1.917
# Iter 100/100 - Loss: 2.137   lengthscale: 0.909   noise: 1.910
# (100000, 25)
# Iter 1/100 - Loss: 2.076   lengthscale: 0.693   noise: 0.693
# Iter 2/100 - Loss: 2.034   lengthscale: 0.744   noise: 0.744
# Iter 3/100 - Loss: 1.999   lengthscale: 0.798   noise: 0.798
# Iter 4/100 - Loss: 1.970   lengthscale: 0.853   noise: 0.852
# Iter 5/100 - Loss: 1.948   lengthscale: 0.910   noise: 0.907
# Iter 6/100 - Loss: 1.930   lengthscale: 0.967   noise: 0.962
# Iter 7/100 - Loss: 1.915   lengthscale: 1.026   noise: 1.017
# Iter 8/100 - Loss: 1.905   lengthscale: 1.084   noise: 1.069
# Iter 9/100 - Loss: 1.896   lengthscale: 1.142   noise: 1.120
# Iter 10/100 - Loss: 1.890   lengthscale: 1.199   noise: 1.167
# Iter 11/100 - Loss: 1.885   lengthscale: 1.256   noise: 1.211
# Iter 12/100 - Loss: 1.882   lengthscale: 1.311   noise: 1.252
# Iter 13/100 - Loss: 1.879   lengthscale: 1.365   noise: 1.287
# Iter 14/100 - Loss: 1.878   lengthscale: 1.418   noise: 1.319
# Iter 15/100 - Loss: 1.876   lengthscale: 1.469   noise: 1.345
# Iter 16/100 - Loss: 1.875   lengthscale: 1.518   noise: 1.367
# Iter 17/100 - Loss: 1.874   lengthscale: 1.565   noise: 1.385
# Iter 18/100 - Loss: 1.874   lengthscale: 1.612   noise: 1.398
# Iter 19/100 - Loss: 1.873   lengthscale: 1.656   noise: 1.406
# Iter 20/100 - Loss: 1.873   lengthscale: 1.699   noise: 1.411
# Iter 21/100 - Loss: 1.872   lengthscale: 1.740   noise: 1.411
# Iter 22/100 - Loss: 1.871   lengthscale: 1.780   noise: 1.408
# Iter 23/100 - Loss: 1.871   lengthscale: 1.819   noise: 1.401
# Iter 24/100 - Loss: 1.870   lengthscale: 1.855   noise: 1.392
# Iter 25/100 - Loss: 1.869   lengthscale: 1.891   noise: 1.379
# Iter 26/100 - Loss: 1.868   lengthscale: 1.925   noise: 1.364
# Iter 27/100 - Loss: 1.868   lengthscale: 1.957   noise: 1.348
# Iter 28/100 - Loss: 1.867   lengthscale: 1.988   noise: 1.329
# Iter 29/100 - Loss: 1.866   lengthscale: 2.017   noise: 1.309
# Iter 30/100 - Loss: 1.865   lengthscale: 2.044   noise: 1.287
# Iter 31/100 - Loss: 1.865   lengthscale: 2.070   noise: 1.265
# Iter 32/100 - Loss: 1.864   lengthscale: 2.094   noise: 1.241
# Iter 33/100 - Loss: 1.863   lengthscale: 2.117   noise: 1.218
# Iter 34/100 - Loss: 1.862   lengthscale: 2.137   noise: 1.194
# Iter 35/100 - Loss: 1.862   lengthscale: 2.156   noise: 1.170
# Iter 36/100 - Loss: 1.861   lengthscale: 2.173   noise: 1.146
# Iter 37/100 - Loss: 1.861   lengthscale: 2.187   noise: 1.123
# Iter 38/100 - Loss: 1.860   lengthscale: 2.200   noise: 1.100
# Iter 39/100 - Loss: 1.860   lengthscale: 2.210   noise: 1.078
# Iter 40/100 - Loss: 1.859   lengthscale: 2.219   noise: 1.056
# Iter 41/100 - Loss: 1.859   lengthscale: 2.225   noise: 1.035
# Iter 42/100 - Loss: 1.858   lengthscale: 2.229   noise: 1.015
# Iter 43/100 - Loss: 1.858   lengthscale: 2.231   noise: 0.996
# Iter 44/100 - Loss: 1.857   lengthscale: 2.231   noise: 0.978
# Iter 45/100 - Loss: 1.857   lengthscale: 2.229   noise: 0.960
# Iter 46/100 - Loss: 1.856   lengthscale: 2.225   noise: 0.944
# Iter 47/100 - Loss: 1.856   lengthscale: 2.218   noise: 0.928
# Iter 48/100 - Loss: 1.855   lengthscale: 2.211   noise: 0.912
# Iter 49/100 - Loss: 1.855   lengthscale: 2.201   noise: 0.898
# Iter 50/100 - Loss: 1.854   lengthscale: 2.190   noise: 0.884
# Iter 51/100 - Loss: 1.854   lengthscale: 2.178   noise: 0.870
# Iter 52/100 - Loss: 1.853   lengthscale: 2.164   noise: 0.857
# Iter 53/100 - Loss: 1.852   lengthscale: 2.149   noise: 0.844
# Iter 54/100 - Loss: 1.852   lengthscale: 2.133   noise: 0.831
# Iter 55/100 - Loss: 1.851   lengthscale: 2.117   noise: 0.818
# Iter 56/100 - Loss: 1.851   lengthscale: 2.100   noise: 0.805
# Iter 57/100 - Loss: 1.850   lengthscale: 2.082   noise: 0.793
# Iter 58/100 - Loss: 1.849   lengthscale: 2.064   noise: 0.780
# Iter 59/100 - Loss: 1.849   lengthscale: 2.046   noise: 0.767
# Iter 60/100 - Loss: 1.848   lengthscale: 2.028   noise: 0.753
# Iter 61/100 - Loss: 1.848   lengthscale: 2.011   noise: 0.740
# Iter 62/100 - Loss: 1.847   lengthscale: 1.993   noise: 0.726
# Iter 63/100 - Loss: 1.847   lengthscale: 1.976   noise: 0.712
# Iter 64/100 - Loss: 1.846   lengthscale: 1.959   noise: 0.698
# Iter 65/100 - Loss: 1.846   lengthscale: 1.943   noise: 0.683
# Iter 66/100 - Loss: 1.845   lengthscale: 1.927   noise: 0.669
# Iter 67/100 - Loss: 1.844   lengthscale: 1.912   noise: 0.654
# Iter 68/100 - Loss: 1.844   lengthscale: 1.898   noise: 0.638
# Iter 69/100 - Loss: 1.843   lengthscale: 1.885   noise: 0.623
# Iter 70/100 - Loss: 1.843   lengthscale: 1.872   noise: 0.607
# Iter 71/100 - Loss: 1.842   lengthscale: 1.860   noise: 0.592
# Iter 72/100 - Loss: 1.842   lengthscale: 1.849   noise: 0.576
# Iter 73/100 - Loss: 1.841   lengthscale: 1.839   noise: 0.561
# Iter 74/100 - Loss: 1.841   lengthscale: 1.829   noise: 0.545
# Iter 75/100 - Loss: 1.840   lengthscale: 1.820   noise: 0.530
# Iter 76/100 - Loss: 1.839   lengthscale: 1.812   noise: 0.515
# Iter 77/100 - Loss: 1.839   lengthscale: 1.804   noise: 0.500
# Iter 78/100 - Loss: 1.838   lengthscale: 1.797   noise: 0.485
# Iter 79/100 - Loss: 1.838   lengthscale: 1.790   noise: 0.470
# Iter 80/100 - Loss: 1.837   lengthscale: 1.784   noise: 0.456
# Iter 81/100 - Loss: 1.837   lengthscale: 1.778   noise: 0.442
# Iter 82/100 - Loss: 1.836   lengthscale: 1.773   noise: 0.428
# Iter 83/100 - Loss: 1.836   lengthscale: 1.768   noise: 0.415
# Iter 84/100 - Loss: 1.835   lengthscale: 1.763   noise: 0.402
# Iter 85/100 - Loss: 1.835   lengthscale: 1.758   noise: 0.389
# Iter 86/100 - Loss: 1.834   lengthscale: 1.754   noise: 0.377
# Iter 87/100 - Loss: 1.834   lengthscale: 1.750   noise: 0.365
# Iter 88/100 - Loss: 1.833   lengthscale: 1.746   noise: 0.353
# Iter 89/100 - Loss: 1.833   lengthscale: 1.742   noise: 0.342
# Iter 90/100 - Loss: 1.832   lengthscale: 1.738   noise: 0.331
# Iter 91/100 - Loss: 1.832   lengthscale: 1.735   noise: 0.321
# Iter 92/100 - Loss: 1.832   lengthscale: 1.732   noise: 0.311
# Iter 93/100 - Loss: 1.831   lengthscale: 1.729   noise: 0.301
# Iter 94/100 - Loss: 1.831   lengthscale: 1.726   noise: 0.291
# Iter 95/100 - Loss: 1.830   lengthscale: 1.723   noise: 0.282
# Iter 96/100 - Loss: 1.830   lengthscale: 1.721   noise: 0.273
# Iter 97/100 - Loss: 1.830   lengthscale: 1.718   noise: 0.265
# Iter 98/100 - Loss: 1.829   lengthscale: 1.717   noise: 0.257
# Iter 99/100 - Loss: 1.829   lengthscale: 1.715   noise: 0.249
# Iter 100/100 - Loss: 1.829   lengthscale: 1.714   noise: 0.241
# (100000, 28)
# Iter 1/100 - Loss: 1.802   lengthscale: 0.693   noise: 0.693
# Iter 2/100 - Loss: 1.784   lengthscale: 0.744   noise: 0.744
# Iter 3/100 - Loss: 1.767   lengthscale: 0.798   noise: 0.797
# Iter 4/100 - Loss: 1.755   lengthscale: 0.853   noise: 0.849
# Iter 5/100 - Loss: 1.747   lengthscale: 0.911   noise: 0.898
# Iter 6/100 - Loss: 1.742   lengthscale: 0.970   noise: 0.942
# Iter 7/100 - Loss: 1.738   lengthscale: 1.031   noise: 0.978
# Iter 8/100 - Loss: 1.735   lengthscale: 1.093   noise: 1.005
# Iter 9/100 - Loss: 1.732   lengthscale: 1.155   noise: 1.021
# Iter 10/100 - Loss: 1.730   lengthscale: 1.218   noise: 1.028
# Iter 11/100 - Loss: 1.728   lengthscale: 1.281   noise: 1.025
# Iter 12/100 - Loss: 1.726   lengthscale: 1.343   noise: 1.014
# Iter 13/100 - Loss: 1.724   lengthscale: 1.405   noise: 0.997
# Iter 14/100 - Loss: 1.722   lengthscale: 1.466   noise: 0.974
# Iter 15/100 - Loss: 1.720   lengthscale: 1.526   noise: 0.947
# Iter 16/100 - Loss: 1.718   lengthscale: 1.585   noise: 0.917
# Iter 17/100 - Loss: 1.716   lengthscale: 1.642   noise: 0.885
# Iter 18/100 - Loss: 1.714   lengthscale: 1.697   noise: 0.852
# Iter 19/100 - Loss: 1.712   lengthscale: 1.749   noise: 0.818
# Iter 20/100 - Loss: 1.711   lengthscale: 1.799   noise: 0.784
# Iter 21/100 - Loss: 1.709   lengthscale: 1.845   noise: 0.752
# Iter 22/100 - Loss: 1.708   lengthscale: 1.888   noise: 0.720
# Iter 23/100 - Loss: 1.707   lengthscale: 1.927   noise: 0.690
# Iter 24/100 - Loss: 1.707   lengthscale: 1.962   noise: 0.662
# Iter 25/100 - Loss: 1.706   lengthscale: 1.992   noise: 0.635
# Iter 26/100 - Loss: 1.705   lengthscale: 2.018   noise: 0.611
# Iter 27/100 - Loss: 1.704   lengthscale: 2.039   noise: 0.589
# Iter 28/100 - Loss: 1.703   lengthscale: 2.056   noise: 0.568
# Iter 29/100 - Loss: 1.702   lengthscale: 2.068   noise: 0.550
# Iter 30/100 - Loss: 1.701   lengthscale: 2.076   noise: 0.533
# Iter 31/100 - Loss: 1.700   lengthscale: 2.080   noise: 0.517
# Iter 32/100 - Loss: 1.699   lengthscale: 2.080   noise: 0.501
# Iter 33/100 - Loss: 1.698   lengthscale: 2.078   noise: 0.487
# Iter 34/100 - Loss: 1.697   lengthscale: 2.072   noise: 0.473
# Iter 35/100 - Loss: 1.696   lengthscale: 2.065   noise: 0.459
# Iter 36/100 - Loss: 1.695   lengthscale: 2.057   noise: 0.446
# Iter 37/100 - Loss: 1.695   lengthscale: 2.047   noise: 0.432
# Iter 38/100 - Loss: 1.694   lengthscale: 2.036   noise: 0.418
# Iter 39/100 - Loss: 1.693   lengthscale: 2.026   noise: 0.404
# Iter 40/100 - Loss: 1.692   lengthscale: 2.015   noise: 0.389
# Iter 41/100 - Loss: 1.692   lengthscale: 2.005   noise: 0.375
# Iter 42/100 - Loss: 1.691   lengthscale: 1.996   noise: 0.360
# Iter 43/100 - Loss: 1.690   lengthscale: 1.988   noise: 0.345
# Iter 44/100 - Loss: 1.690   lengthscale: 1.981   noise: 0.330
# Iter 45/100 - Loss: 1.689   lengthscale: 1.975   noise: 0.315
# Iter 46/100 - Loss: 1.688   lengthscale: 1.970   noise: 0.301
# Iter 47/100 - Loss: 1.688   lengthscale: 1.967   noise: 0.287
# Iter 48/100 - Loss: 1.687   lengthscale: 1.964   noise: 0.273
# Iter 49/100 - Loss: 1.686   lengthscale: 1.963   noise: 0.259
# Iter 50/100 - Loss: 1.686   lengthscale: 1.962   noise: 0.246
# Iter 51/100 - Loss: 1.685   lengthscale: 1.962   noise: 0.234
# Iter 52/100 - Loss: 1.685   lengthscale: 1.962   noise: 0.222
# Iter 53/100 - Loss: 1.684   lengthscale: 1.963   noise: 0.211
# Iter 54/100 - Loss: 1.684   lengthscale: 1.963   noise: 0.200
# Iter 55/100 - Loss: 1.683   lengthscale: 1.963   noise: 0.190
# Iter 56/100 - Loss: 1.683   lengthscale: 1.963   noise: 0.181
# Iter 57/100 - Loss: 1.682   lengthscale: 1.963   noise: 0.172
# Iter 58/100 - Loss: 1.682   lengthscale: 1.962   noise: 0.163
# Iter 59/100 - Loss: 1.681   lengthscale: 1.960   noise: 0.156
# Iter 60/100 - Loss: 1.681   lengthscale: 1.958   noise: 0.148
# Iter 61/100 - Loss: 1.681   lengthscale: 1.955   noise: 0.141
# Iter 62/100 - Loss: 1.680   lengthscale: 1.951   noise: 0.135
# Iter 63/100 - Loss: 1.680   lengthscale: 1.947   noise: 0.129
# Iter 64/100 - Loss: 1.680   lengthscale: 1.943   noise: 0.124
# Iter 65/100 - Loss: 1.679   lengthscale: 1.938   noise: 0.118
# Iter 66/100 - Loss: 1.679   lengthscale: 1.933   noise: 0.113
# Iter 67/100 - Loss: 1.679   lengthscale: 1.929   noise: 0.109
# Iter 68/100 - Loss: 1.679   lengthscale: 1.924   noise: 0.104
# Iter 69/100 - Loss: 1.679   lengthscale: 1.920   noise: 0.100
# Iter 70/100 - Loss: 1.678   lengthscale: 1.917   noise: 0.096
# Iter 71/100 - Loss: 1.678   lengthscale: 1.913   noise: 0.093
# Iter 72/100 - Loss: 1.678   lengthscale: 1.911   noise: 0.089
# Iter 73/100 - Loss: 1.678   lengthscale: 1.909   noise: 0.086
# Iter 74/100 - Loss: 1.678   lengthscale: 1.907   noise: 0.083
# Iter 75/100 - Loss: 1.677   lengthscale: 1.906   noise: 0.080
# Iter 76/100 - Loss: 1.677   lengthscale: 1.906   noise: 0.077
# Iter 77/100 - Loss: 1.677   lengthscale: 1.906   noise: 0.075
# Iter 78/100 - Loss: 1.677   lengthscale: 1.906   noise: 0.072
# Iter 79/100 - Loss: 1.677   lengthscale: 1.907   noise: 0.070
# Iter 80/100 - Loss: 1.677   lengthscale: 1.907   noise: 0.068
# Iter 81/100 - Loss: 1.677   lengthscale: 1.908   noise: 0.066
# Iter 82/100 - Loss: 1.677   lengthscale: 1.909   noise: 0.064
# Iter 83/100 - Loss: 1.676   lengthscale: 1.909   noise: 0.062
# Iter 84/100 - Loss: 1.676   lengthscale: 1.909   noise: 0.060
# Iter 85/100 - Loss: 1.676   lengthscale: 1.910   noise: 0.058
# Iter 86/100 - Loss: 1.676   lengthscale: 1.910   noise: 0.057
# Iter 87/100 - Loss: 1.676   lengthscale: 1.909   noise: 0.055
# Iter 88/100 - Loss: 1.676   lengthscale: 1.909   noise: 0.054
# Iter 89/100 - Loss: 1.676   lengthscale: 1.908   noise: 0.052
# Iter 90/100 - Loss: 1.676   lengthscale: 1.907   noise: 0.051
# Iter 91/100 - Loss: 1.676   lengthscale: 1.907   noise: 0.050
# Iter 92/100 - Loss: 1.676   lengthscale: 1.906   noise: 0.049
# Iter 93/100 - Loss: 1.676   lengthscale: 1.905   noise: 0.048
# Iter 94/100 - Loss: 1.676   lengthscale: 1.904   noise: 0.046
# Iter 95/100 - Loss: 1.675   lengthscale: 1.904   noise: 0.045
# Iter 96/100 - Loss: 1.675   lengthscale: 1.903   noise: 0.044
# Iter 97/100 - Loss: 1.675   lengthscale: 1.903   noise: 0.043
# Iter 98/100 - Loss: 1.675   lengthscale: 1.903   noise: 0.043
# Iter 99/100 - Loss: 1.675   lengthscale: 1.903   noise: 0.042
# Iter 100/100 - Loss: 1.675   lengthscale: 1.903   noise: 0.041
# (100000, 31)

# %%
np.save('master_acquisition.npy',master_acquisition)

# %%
""" STructure of master_acquisition_array: 7 parameters, model_mean_PC1, model_var_PC1, ei_PC1, 
                                      model_mean_PC2, model_var_PC12, ei_PC2, .....
"""

master_acquisition = np.load("master_acquisition.npy",)
